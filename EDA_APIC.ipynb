# %%
#Sebagai pemanasan sebelum Anda memulai proyek ini, buatlah sebuah vektor karakter dengan 3 elemen dengan nama bersatulawancovid yang merupakan kunci dasar menghindari COVID-19! Jangan lupa untuk mencetak vektor bersatulawancovid tersebut pada layar konsol!



bersatulawancovid = [cuci tangan', 'pakai masker', 'jaga jarak']
#print(bersatulawancovid)
# Out:
#   File "<ipython-input-1-285868404757>", line 5
#     bersatulawancovid = [cuci tangan', 'pakai masker', 'jaga jarak']
#                                    ^
# SyntaxError: invalid syntax

# %%
# Rekapitulasi data COVID-19 Indonesia tersedia dalam API publik yang beralamat : https://data.covid19.go.id/public/api/update.json.

#import requests
resp = requests.get('https://data.covid19.go.id/public/api/update.json')

# %%
#Saat Anda menjalankan fungsi get(), pada dasarnya hal yang terjadi adalah Anda membuat sebuah permintaan kepada server penyedia API. 
#Permintaan Anda tersebut selanjutnya diproses dan dijawab oleh server sebagai sebuah respon.
# Objek resp yang telah Anda buat memiliki informasi respon oleh server.
#Ada tiga informasi utama dalam sebuah respon API, yaitu status, headers, dan body. 
#Status memiliki informasi apakah permintaan Anda berhasil atau tidak dan dinyatakan dalam status code, 
#headers umumnya mengandung informasi metadata, sedangkan body berisikan konten atas permintaan yang telah dibuat.

# %%
print(resp)
# Out:
# <Response [200]>

# %%
print(resp.headers)
# Out:
# {'Server': 'nginx', 'Date': 'Sat, 14 Aug 2021 10:24:44 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Accept-Encoding', 'Last-Modified': 'Sat, 14 Aug 2021 10:23:58 GMT', 'ETag': 'W/"611799be-320b2"', 'X-Content-Type-Options': 'nosniff, nosniff', 'X-XSS-Protection': '1; mode=block, 1; mode=block', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Content-Encoding': 'gzip'}

# %% [markdown]
# ***Mengekstrak Isi Respon***
# Respon API dengan status code 200 menyatakan bahwa ***permintaan Anda berhasil ***dipenuhi dan konten yang diminta tersedia untuk diekstrak. Selain itu Anda juga telah mengetahui lewat attribut headers bahwa konten yang diminta tersedia dalam bentuk application/json, yaitu berkas JSON.
#
# Selanjutnya Anda dapat mengekstrak konten tersebut dengan menggunakan*** method json()***. Method json() merupakan builtin JSON decoder untuk mengekstrak content bertipe JSON. Anda juga dapat menggunakan attribut content tetapi ini berupa binary content yang perlu Anda proses kembali nantinya. Jalankan method json() pada obyek resp dan simpanlah hasilnya sebagai cov_id_raw!

# %%
cov_id_raw = resp.json()

# %%
#cov_id_raw
# Out:
# {'data': {'id': 1,
#   'jumlah_odp': 308852,
#   'jumlah_pdp': 0,
#   'total_spesimen': 28966108,
#   'total_spesimen_negatif': 20156355},
#  'update': {'harian': [{'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583107200000,
#     'key_as_string': '2020-03-02T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583193600000,
#     'key_as_string': '2020-03-03T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583280000000,
#     'key_as_string': '2020-03-04T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583366400000,
#     'key_as_string': '2020-03-05T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 4},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 4},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583452800000,
#     'key_as_string': '2020-03-06T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 4},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 4},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583539200000,
#     'key_as_string': '2020-03-07T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 6},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 6},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583625600000,
#     'key_as_string': '2020-03-08T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 13},
#     'jumlah_dirawat_kum': {'value': 19},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 13},
#     'jumlah_positif_kum': {'value': 19},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583712000000,
#     'key_as_string': '2020-03-09T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 6},
#     'jumlah_dirawat_kum': {'value': 25},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 8},
#     'jumlah_positif_kum': {'value': 27},
#     'jumlah_sembuh': {'value': 2},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583798400000,
#     'key_as_string': '2020-03-10T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 6},
#     'jumlah_dirawat_kum': {'value': 31},
#     'jumlah_meninggal': {'value': 1},
#     'jumlah_meninggal_kum': {'value': 1},
#     'jumlah_positif': {'value': 7},
#     'jumlah_positif_kum': {'value': 34},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583884800000,
#     'key_as_string': '2020-03-11T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 31},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 1},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 34},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583971200000,
#     'key_as_string': '2020-03-12T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 32},
#     'jumlah_dirawat_kum': {'value': 63},
#     'jumlah_meninggal': {'value': 3},
#     'jumlah_meninggal_kum': {'value': 4},
#     'jumlah_positif': {'value': 35},
#     'jumlah_positif_kum': {'value': 69},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1584057600000,
#     'key_as_string': '2020-03-13T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 20},
#     'jumlah_dirawat_kum': {'value': 83},
#     'jumlah_meninggal': {'value': 1},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 27},
#     'jumlah_positif_kum': {'value': 96},
#     'jumlah_sembuh': {'value': 6},
#     'jumlah_sembuh_kum': {'value': 8},
#     'key': 1584144000000,
#     'key_as_string': '2020-03-14T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 21},
#     'jumlah_dirawat_kum': {'value': 104},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 21},
#     'jumlah_positif_kum': {'value': 117},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 8},
#     'key': 1584230400000,
#     'key_as_string': '2020-03-15T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 17},
#     'jumlah_dirawat_kum': {'value': 121},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 17},
#     'jumlah_positif_kum': {'value': 134},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 8},
#     'key': 1584316800000,
#     'key_as_string': '2020-03-16T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 37},
#     'jumlah_dirawat_kum': {'value': 158},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 38},
#     'jumlah_positif_kum': {'value': 172},
#     'jumlah_sembuh': {'value': 1},
#     'jumlah_sembuh_kum': {'value': 9},
#     'key': 1584403200000,
#     'key_as_string': '2020-03-17T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 39},
#     'jumlah_dirawat_kum': {'value': 197},
#     'jumlah_meninggal': {'value': 14},
#     'jumlah_meninggal_kum': {'value': 19},
#     'jumlah_positif': {'value': 55},
#     'jumlah_positif_kum': {'value': 227},
#     'jumlah_sembuh': {'value': 2},
#     'jumlah_sembuh_kum': {'value': 11},
#     'key': 1584489600000,
#     'key_as_string': '2020-03-18T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 72},
#     'jumlah_dirawat_kum': {'value': 269},
#     'jumlah_meninggal': {'value': 6},
#     'jumlah_meninggal_kum': {'value': 25},
#     'jumlah_positif': {'value': 82},
#     'jumlah_positif_kum': {'value': 309},
#     'jumlah_sembuh': {'value': 4},
#     'jumlah_sembuh_kum': {'value': 15},
#     'key': 1584576000000,
#     'key_as_string': '2020-03-19T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 51},
#     'jumlah_dirawat_kum': {'value': 320},
#     'jumlah_meninggal': {'value': 7},
#     'jumlah_meninggal_kum': {'value': 32},
#     'jumlah_positif': {'value': 60},
#     'jumlah_positif_kum': {'value': 369},
#     'jumlah_sembuh': {'value': 2},
#     'jumlah_sembuh_kum': {'value': 17},
#     'key': 1584662400000,
#     'key_as_string': '2020-03-20T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 72},
#     'jumlah_dirawat_kum': {'value': 392},
#     'jumlah_meninggal': {'value': 6},
#     'jumlah_meninggal_kum': {'value': 38},
#     'jumlah_positif': {'value': 81},
#     'jumlah_positif_kum': {'value': 450},
#     'jumlah_sembuh': {'value': 3},
#     'jumlah_sembuh_kum': {'value': 20},
#     'key': 1584748800000,
#     'key_as_string': '2020-03-21T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value':
00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -25725},
#     'jumlah_dirawat_kum': {'value': 448508},
#     'jumlah_meninggal': {'value': 1475},
#     'jumlah_meninggal_kum': {'value': 108571},
#     'jumlah_positif': {'value': 20709},
#     'jumlah_positif_kum': {'value': 3686740},
#     'jumlah_sembuh': {'value': 44959},
#     'jumlah_sembuh_kum': {'value': 3129661},
#     'key': 1628467200000,
#     'key_as_string': '2021-08-09T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -11453},
#     'jumlah_dirawat_kum': {'value': 437055},
#     'jumlah_meninggal': {'value': 2048},
#     'jumlah_meninggal_kum': {'value': 110619},
#     'jumlah_positif': {'value': 32081},
#     'jumlah_positif_kum': {'value': 3718821},
#     'jumlah_sembuh': {'value': 41486},
#     'jumlah_sembuh_kum': {'value': 3171147},
#     'key': 1628553600000,
#     'key_as_string': '2021-08-10T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -10885},
#     'jumlah_dirawat_kum': {'value': 426170},
#     'jumlah_meninggal': {'value': 1579},
#     'jumlah_meninggal_kum': {'value': 112198},
#     'jumlah_positif': {'value': 30625},
#     'jumlah_positif_kum': {'value': 3749446},
#     'jumlah_sembuh': {'value': 39931},
#     'jumlah_sembuh_kum': {'value': 3211078},
#     'key': 1628640000000,
#     'key_as_string': '2021-08-11T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -13394},
#     'jumlah_dirawat_kum': {'value': 412776},
#     'jumlah_meninggal': {'value': 1466},
#     'jumlah_meninggal_kum': {'value': 113664},
#     'jumlah_positif': {'value': 24709},
#     'jumlah_positif_kum': {'value': 3774155},
#     'jumlah_sembuh': {'value': 36637},
#     'jumlah_sembuh_kum': {'value': 3247715},
#     'key': 1628726400000,
#     'key_as_string': '2021-08-12T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -12647},
#     'jumlah_dirawat_kum': {'value': 400129},
#     'jumlah_meninggal': {'value': 1432},
#     'jumlah_meninggal_kum': {'value': 115096},
#     'jumlah_positif': {'value': 30788},
#     'jumlah_positif_kum': {'value': 3804943},
#     'jumlah_sembuh': {'value': 42003},
#     'jumlah_sembuh_kum': {'value': 3289718},
#     'key': 1628812800000,
#     'key_as_string': '2021-08-13T00:00:00.000Z'}],
#   'penambahan': {'created': '2021-08-13 18:02:29',
#    'jumlah_dirawat': -12647,
#    'jumlah_meninggal': 1432,
#    'jumlah_positif': 30788,
#    'jumlah_sembuh': 42003,
#    'tanggal': '2021-08-13'},
#   'total': {'jumlah_dirawat': 400129,
#    'jumlah_meninggal': 115096,
#    'jumlah_positif': 3804943,
#    'jumlah_sembuh': 3289718}}}

# %% [markdown]
# Dengan menggunakan fungsi len() dan method keys() cobalah amati ada berapa komponen serta apa saja nama komponen dalam obyek cov_id_raw tersebut! Kemudian ekstraklah key ke-2 dan simpan dengan nama cov_id_update.

# %%
print('Length of cov_id_raw : %d.' %len(cov_id_raw))
print('Komponen cov_id_raw : %s.' %cov_id_raw.keys())
cov_id_update = cov_id_raw['update']
# Out:
# Length of cov_id_raw : 2.
# Komponen cov_id_raw : dict_keys(['data', 'update']).

# %% [markdown]
# ***Apa Kabar Jawa Barat?***
# Anda telah berhasil menjawab pertanyaan mengenai kondisi COVID-19 di Indonesia dengan menggunakan data yang langsung diambil menggunakan API. Namun bagaimana jika Anda ingin berfokus dengan data COVID-19 di provinsi tempat menetap saat ini?
#
# covid19.go.id menyediakan data kasus COVID-19 tingkat provinsi di alamat API yang berbeda. Sebagai data mengenai COVID-19 Jawa Barat, tempat tinggal saya sekarang, tersedia di https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json.

# %%
import requests
resp_jabar = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json')
cov_jabar_raw = resp_jabar.json()

# %%
cov_jabar_raw
# Out:
# {'data': {'kasus': {'gejala': {'current_data': 1434,
#     'list_data': [{'doc_count': 66.31799163179917, 'key': 'BATUK'},
#      {'doc_count': 49.651324965132495, 'key': 'PILEK'},
#      {'doc_count': 38.77266387726639, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 28.10320781032078, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 26.29009762900976, 'key': 'DEMAM'},
#      {'doc_count': 26.29009762900976, 'key': 'LEMAS'},
#      {'doc_count': 26.15062761506276, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 23.91910739191074, 'key': 'SESAK NAPAS'},
#      {'doc_count': 18.549511854951188, 'key': 'KERAM OTOT'},
#      {'doc_count': 14.923291492329149, 'key': 'MUAL'},
#      {'doc_count': 7.670850767085077, 'key': 'SAKIT PERUT'},
#      {'doc_count': 5.160390516039052, 'key': 'DIARE'},
#      {'doc_count': 2.161785216178522, 'key': 'MENGGIGIL'}],
#     'missing_data': 99.77991755349355},
#    'jenis_kelamin': {'current_data': 639731,
#     'list_data': [{'doc_count': 48.81317303679203, 'key': 'LAKI-LAKI'},
#      {'doc_count': 51.18682696320798, 'key': 'PEREMPUAN'}],
#     'missing_data': 1.8175986150460233},
#    'kelompok_umur': {'current_data': 638542,
#     'list_data': [{'doc_count': 3.2536622493117133,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 11.28586686545286, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 24.798212177115992,
#       'key': '19-30',
#       'usia': {'value': 30.0}},
#      {'doc_count': 28.23933272987525, 'key': '31-45', 'usia': {'value': 45.0}},
#      {'doc_count': 21.82816478790745, 'key': '46-59', 'usia': {'value': 59.0}},
#      {'doc_count': 10.594761190336737,
#       'key': '≥ 60',
#       'usia': {'value': 9783561644.0}}],
#     'missing_data': 2.000079806744907},
#    'kondisi_penyerta': {'current_data': 307,
#     'list_data': [{'doc_count': 50.4885993485342, 'key': 'HIPERTENSI'},
#      {'doc_count': 26.710097719869708, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 19.86970684039088, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 14.332247557003258, 'key': 'HAMIL'},
#      {'doc_count': 6.514657980456026, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 4.234527687296417,
#       'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 2.2801302931596092, 'key': 'PENYAKIT GINJAL'},
#      {'doc_count': 1.6286644951140066, 'key': 'KANKER'},
#      {'doc_count': 1.3029315960912053, 'key': 'GANGGUAN IMUN'},
#      {'doc_count': 0.9771986970684038, 'key': 'ASMA'},
#      {'doc_count': 0.6514657980456027, 'key': 'PENYAKIT HATI'}],
#     'missing_data': 99.95288332560845}},
#   'last_update': '2021-08-13',
#   'meninggal': {'gejala': {'list_data': [{'doc_count': 4.672245467224546,
#       'key': 'BATUK'},
#      {'doc_count': 4.323570432357044, 'key': 'SESAK NAPAS'},
#      {'doc_count': 3.556485355648536, 'key': 'DEMAM'},
#      {'doc_count': 3.556485355648536, 'key': 'LEMAS'},
#      {'doc_count': 3.417015341701534, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 2.580195258019526, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 2.2315202231520224, 'key': 'PILEK'},
#      {'doc_count': 1.9525801952580195, 'key': 'KERAM OTOT'},
#      {'doc_count': 1.9525801952580195, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 1.6039051603905161, 'key': 'MUAL'},
#      {'doc_count': 0.7670850767085077, 'key': 'SAKIT PERUT'},
#      {'doc_count': 0.697350069735007, 'key': 'MENGGIGIL'},
#      {'doc_count': 0.4881450488145049, 'key': 'DIARE'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 51.20170909738294,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 48.798290902617055, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 0.7062658457080767,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 1.466859833393698, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 5.306048533140166, 'key': '19-30', 'usia': {'value': 30.0}},
#      {'doc_count': 15.565012676566461,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 38.20173850054328, 'key': '46-59', 'usia': {'value': 59.0}},
#      {'doc_count': 38.75407461064832,
#       'key': '≥ 60',
#       'usia': {'value': 2021.0}}]},
#    'kondisi_penyerta': {'list_data': [{'doc_count': 6.840390879478828,
#       'key': 'HIPERTENSI'},
#      {'doc_count': 6.188925081433225, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 4.88599348534202, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 3.257328990228013, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 1.3029315960912053, 'key': 'PENYAKIT GINJAL'},
#      {'doc_count': 1.3029315960912053,
#       'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 0.9771986970684038, 'key': 'HAMIL'},
#      {'doc_count': 0.9771986970684038, 'key': 'KANKER'},
#      {'doc_count': 0.6514657980456027, 'key': 'ASMA'},
#      {'doc_count': 0.32573289902280134, 'key': 'GANGGUAN IMUN'}]}},
#   'perawatan': {'gejala': {'list_data': [{'doc_count': 0.1394700139470014,
#       'key': 'MUAL'},
#      {'doc_count': 0.0697350069735007, 'key': 'DIARE'},
#      {'doc_count': 0.0697350069735007, 'key': 'LEMAS'},
#      {'doc_count': 0.0697350069735007, 'key': 'PILEK'},
#      {'doc_count': 0.0697350069735007, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 0.0697350069735007, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 0.0697350069735007, 'key': 'SESAK NAPAS'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 50.019425925062556,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 49.98057407493745, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 3.4671929879091166,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 11.236129673950208, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 23.8025673701551, 'key': '19-30', 'usia': {'value': 30.0}},
#      {'doc_count': 28.213097939265847,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 21.477636527523078,
#       'key': '46-59',
#       'usia': {'value': 59.0}},
#      {'doc_count': 11.803375501196655,
#       'key': '≥ 60',
#       'usia': {'value': 2012.0}}]},
#    'kondisi_penyerta': {'list_data': []}},
#   'sembuh': {'gejala': {'list_data': [{'doc_count': 61.645746164574625,
#       'key': 'BATUK'},
#      {'doc_count': 47.35006973500697, 'key': 'PILEK'},
#      {'doc_count': 35.35564853556485, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 26.08089260808926, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 23.500697350069736, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 22.733612273361228, 'key': 'DEMAM'},
#      {'doc_count': 22.66387726638773, 'key': 'LEMAS'},
#      {'doc_count': 19.525801952580196, 'key': 'SESAK NAPAS'},
#      {'doc_count': 16.596931659693166, 'key': 'KERAM OTOT'},
#      {'doc_count': 13.179916317991633, 'key': 'MUAL'},
#      {'doc_count': 6.903765690376569, 'key': 'SAKIT PERUT'},
#      {'doc_count': 4.602510460251046, 'key': 'DIARE'},
#      {'doc_count': 1.4644351464435146, 'key': 'MENGGIGIL'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 48.628024461579365,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 51.371975538420635, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 3.279221240446629,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 11.48411086172117, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 25.294236724720857,
#       'key': '19-30',
#       'usia': {'value': 30.0}},
#      {'doc_count': 28.490887007415406,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 21.547113390345768,
#       'key': '46-59',
#       'usia': {'value': 59.0}},
#      {'doc_count': 9.904430775350171,
#       'key': '≥ 60',
#       'usia': {'value': 9783561644.0}}]},
#    'kondisi_penyerta': {'list_data': [{'doc_count': 43.648208469055376,
#       'key': 'HIPERTENSI'},
#      {'doc_count': 20.521172638436482, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 14.983713355048861, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 13.355048859934854, 'key': 'HAMIL'},
#      {'doc_count': 3.257328990228013, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 2.9315960912052117,
#       'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 0.9771986970684038, 'key': 'GANGGUAN IMUN'},
#      {'doc_count': 0.9771986970684038, 'key': 'PENYAKIT GINJAL'},
#      {'doc_count': 0.6514657980456027, 'key': 'KANKER'},
#      {'doc_count': 0.6514657980456027, 'key': 'PENYAKIT HATI'},
#      {'doc_count': 0.32573289902280134, 'key': 'ASMA'}]}}},
#  'kasus_dengan_tgl': 651574,
#  'kasus_tanpa_tgl': 0,
#  'kasus_total': 651574,
#  'last_date': '2021-08-13',
#  'list_perkembangan': [{'AKUMULASI_DIRAWAT_OR_ISOLASI': 3,
#    'AKUMULASI_KASUS': 3,
#    'AKUMULASI_MENINGGAL': 0,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 3,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583107200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3,
#    'AKUMULASI_KASUS': 4,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 1,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1583193600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 4,
#    'AKUMULASI_KASUS': 5,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583280000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 5,
#    'AKUMULASI_KASUS': 6,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583366400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583452800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583539200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583625600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583712000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583798400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 5,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': -1,
#    'KASUS': 0,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1583884800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 8,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583971200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 4,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1584057600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584144000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584230400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 7,
#    'AKUMULASI_KASUS': 13,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584316800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 18,
#    'AKUMULASI_KASUS': 24,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 11,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584403200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 21,
#    'AKUMULASI_KASUS': 29,
#    'AKUMULASI_MENINGGAL': 3,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 5,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1584489600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27,
#    'AKUMULASI_KASUS': 36,
#    'AKUMULASI_MENINGGAL': 4,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 7,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1584576000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 44,
#    'AKUMULASI_KASUS': 56,
#    'AKUMULASI_MENINGGAL': 7,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 20,
#    'MENINGGAL': 3,
#    'SEMBUH': 0,
#    'tanggal': 1584662400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 49,
#    'AKUMULASI_KASUS': 61,
#    'AKUMULASI_MENINGGAL': 7,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 5,
#    'KASUS': 5,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584748800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 49,
#    'AKUMULASI_KASUS': 64,
#    'AKUMULASI_MENINGGAL': 10,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 3,
#    'MENINGGAL': 3,
#    'SEMBUH': 0,
#    'tanggal': 1584835200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 51,
#    'AKUMULASI_KASUS': 70,
#    'AKUMULASI_MENINGGAL': 14,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 6,
#    'MENINGGAL': 4,
#    'SEMBUH': 0,
#    'tanggal': 1584921600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 50,
#    'AKUMULASI_KASUS': 72,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 6,
#    'DIRAWAT_OR_ISOLASI': -1,
#    'KASUS': 2,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585008000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 54,
#    'AKUMULASI_KASUS': 77,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 4,
#    'KASUS': 5,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1585094400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 62,
#    'AKUMULASI_KASUS': 85,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 8,
#    'KASUS': 8,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1585180800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 85,
#    'AKUMULASI_KASUS': 112,
#    'AKUMULASI_MENINGGAL': 20,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 23,
#    'KASUS': 27,
#    'MENINGGAL': 4,
#    'SEMBUH': 0,
#    'tanggal': 1585267200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 105,
#    'AKUMULASI_KASUS': 135,
#    'AKUMULASI_MENINGGAL': 22,
#    'AKUMULASI_SEMBUH': 8,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 23,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585353600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 135,
#    'AKUMULASI_KASUS': 168,
#    'AKUMULASI_MENINGGAL': 24,
#    'AKUMULASI_SEMBUH': 9,
#    'DIRAWAT_OR_ISOLASI': 30,
#    'KASUS': 33,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585440000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 156,
#    'AKUMULASI_KASUS': 194,
#    'AKUMULASI_MENINGGAL': 26,
#    'AKUMULASI_SEMBUH': 12,
#    'DIRAWAT_OR_ISOLASI': 21,
#    'KASUS': 26,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1585526400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 162,
#    'AKUMULASI_KASUS': 203,
#    'AKUMULASI_MENINGGAL': 26,
#    'AKUMULASI_SEMBUH': 15,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 9,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1585612800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 197,
#    'AKUMULASI_KASUS': 239,
#    'AKUMULASI_MENINGGAL': 27,
#    'AKUMULASI_SEMBUH': 15,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 36,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1585699200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 216,
#    'AKUMULASI_KASUS': 263,
#    'AKUMULASI_MENINGGAL': 31,
#    'AKUMULASI_SEMBUH': 16,
#    'DIRAWAT_OR_ISOLASI': 19,
#    'KASUS': 24,
#    'MENINGGAL': 4,
#    'SEMBUH': 1,
#    'tanggal': 1585785600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 214,
#    'AKUMULASI_KASUS': 265,
#    'AKUMULASI_MENINGGAL': 32,
#    'AKUMULASI_SEMBUH': 19,
#    'DIRAWAT_OR_ISOLASI': -2,
#    'KASUS': 2,
#    'MENINGGAL': 1,
#    'SEMBUH': 3,
#    'tanggal': 1585872000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 236,
#    'AKUMULASI_KASUS': 289,
#    'AKUMULASI_MENINGGAL': 34,
#    'AKUMULASI_SEMBUH': 19,
#    'DIRAWAT_OR_ISOLASI': 22,
#    'KASUS': 24,
#    'MENINGGAL': 2,
#    'SEMBUH': 0,
#    'tanggal': 1585958400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 245,
#    'AKUMULASI_KASUS': 299,
#    'AKUMULASI_MENINGGAL': 34,
#    'AKUMULASI_SEMBUH': 20,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 10,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1586044800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 262,
#    'AKUMULASI_KASUS': 319,
#    'AKUMULASI_MENINGGAL': 36,
#    'AKUMULASI_SEMBUH': 21,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 20,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1586131200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 336,
#    'AKUMULASI_KASUS': 398,
#    'AKUMULASI_MENINGGAL': 38,
#    'AKUMULASI_SEMBUH': 24,
#    'DIRAWAT_OR_ISOLASI': 74,
#    'KASUS': 79,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1586217600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 354,
#    'AKUMULASI_KASUS': 422,
#    'AKUMULASI_MENINGGAL': 43,
#    'AKUMULASI_SEMBUH': 25,
#    'DIRAWAT_OR_ISOLASI': 18,
#    'KASUS': 24,
#    'MENINGGAL': 5,
#    'SEMBUH': 1,
#    'tanggal': 1586304000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 370,
#    'AKUMULASI_KASUS': 444,
#    'AKUMULASI_MENINGGAL': 48,
#    'AKUMULASI_SEMBUH': 26,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 22,
#    'MENINGGAL': 5,
#    'SEMBUH': 1,
#    'tanggal': 1586390400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 379,
#    'AKUMULASI_KASUS': 454,
#    'AKUMULASI_MENINGGAL': 48,
#    'AKUMULASI_SEMBUH': 27,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 10,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1586476800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 422,
#    'AKUMULASI_KASUS': 499,
#    'AKUMULASI_MENINGGAL': 49,
#    'AKUMULASI_SEMBUH': 28,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 45,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1586563200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 450,
#    'AKUMULASI_KASUS': 534,
#    'AKUMULASI_MENINGGAL': 53,
#    'AKUMULASI_SEMBUH': 31,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 35,
#    'MENINGGAL': 4,
#    'SEMBUH': 3,
#    'tanggal': 1586649600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 513,
#    'AKUMULASI_KASUS': 610,
#    'AKUMULASI_MENINGGAL': 63,
#    'AKUMULASI_SEMBUH': 34,
#    'DIRAWAT_OR_ISOLASI': 63,
#    'KASUS': 76,
#    'MENINGGAL': 10,
#    'SEMBUH': 3,
#    'tanggal': 1586736000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 517,
#    'AKUMULASI_KASUS': 616,
#    'AKUMULASI_MENINGGAL': 64,
#    'AKUMULASI_SEMBUH': 35,
#    'DIRAWAT_OR_ISOLASI': 4,
#    'KASUS': 6,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1586822400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 551,
#    'AKUMULASI_KASUS': 654,
#    'AKUMULASI_MENINGGAL': 67,
#    'AKUMULASI_SEMBUH': 36,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 38,
#    'MENINGGAL': 3,
#    'SEMBUH': 1,
#    'tanggal': 1586908800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 567,
#    'AKUMULASI_KASUS': 677,
#    'AKUMULASI_MENINGGAL': 68,
#    'AKUMULASI_SEMBUH': 42,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 23,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1586995200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 609,
#    'AKUMULASI_KASUS': 738,
#    'AKUMULASI_MENINGGAL': 71,
#    'AKUMULASI_SEMBUH': 58,
#    'DIRAWAT_OR_ISOLASI': 42,
#    'KASUS': 61,
#    'MENINGGAL': 3,
#    'SEMBUH': 16,
#    'tanggal': 1587081600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 626,
#    'AKUMULASI_KASUS': 757,
#    'AKUMULASI_MENINGGAL': 71,
#    'AKUMULASI_SEMBUH': 60,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 19,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1587168000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 667,
#    'AKUMULASI_KASUS': 811,
#    'AKUMULASI_MENINGGAL': 72,
#    'AKUMULASI_SEMBUH': 72,
#    'DIRAWAT_OR_ISOLASI': 41,
#    'KASUS': 54,
#    'MENINGGAL': 1,
#    'SEMBUH': 12,
#    'tanggal': 1587254400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 687,
#    'AKUMULASI_KASUS': 838,
#    'AKUMULASI_MENINGGAL': 75,
#    'AKUMULASI_SEMBUH': 76,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 27,
#    'MENINGGAL': 3,
#    'SEMBUH': 4,
#    'tanggal': 1587340800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 682,
#    'AKUMULASI_KASUS': 857,
#    'AKUMULASI_MENINGGAL': 80,
#    'AKUMULASI_SEMBUH': 95,
#    'DIRAWAT_OR_ISOLASI': -5,
#    'KASUS': 19,
#    'MENINGGAL': 5,
#    'SEMBUH': 19,
#    'tanggal': 1587427200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 684,
#    'AKUMULASI_KASUS': 865,
#    'AKUMULASI_MENINGGAL': 83,
#    'AKUMULASI_SEMBUH': 98,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 8,
#    'MENINGGAL': 3,
#    'SEMBUH': 3,
#    'tanggal': 1587513600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 701,
#    'AKUMULASI_KASUS': 894,
#    'AKUMULASI_MENINGGAL': 86,
#    'AKUMULASI_SEMBUH': 107,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 29,
#    'MENINGGAL': 3,
#    'SEMBUH': 9,
#    'tanggal': 1587600000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 770,
#    'AKUMULASI_KASUS': 968,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 110,
#    'DIRAWAT_OR_ISOLASI': 69,
#    'KASUS': 74,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1587686400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 813,
#    'AKUMULASI_KASUS': 1015,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 114,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 47,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1587772800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 824,
#    'AKUMULASI_KASUS': 1027,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 115,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 12,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1587859200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 858,
#    'AKUMULASI_KASUS': 1065,
#    'AKUMULASI_MENINGGAL': 89,
#    'AKUMULASI_SEMBUH': 118,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 38,
#    'MENINGGAL': 1,
#    'SEMBUH': 3,
#    'tanggal': 1587945600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 870,
#    'AKUMULASI_KASUS': 1084,
#    'AKUMULASI_MENINGGAL': 90,
#    'AKUMULASI_SEMBUH': 124,
#    'DIRAWAT_OR_ISOLASI': 12,
#    'KASUS': 19,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1588032000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 903,
#    'AKUMULASI_KASUS': 1124,
#    'AKUMULASI_MENINGGAL': 90,
#    'AKUMULASI_SEMBUH': 131,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 40,
#    'MENINGGAL': 0,
#    'SEMBUH': 7,
#    'tanggal': 1588118400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 873,
#    'AKUMULASI_KASUS': 1129,
#    'AKUMULASI_MENINGGAL': 94,
#    'AKUMULASI_SEMBUH': 162,
#    'DIRAWAT_OR_ISOLASI': -30,
#    'KASUS': 5,
#    'MENINGGAL': 4,
#    'SEMBUH': 31,
#    'tanggal': 1588204800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 869,
#    'AKUMULASI_KASUS': 1133,
#    'AKUMULASI_MENINGGAL': 99,
#    'AKUMULASI_SEMBUH': 165,
#    'DIRAWAT_OR_ISOLASI': -4,
#    'KASUS': 4,
#    'MENINGGAL': 5,
#    'SEMBUH': 3,
#    'tanggal': 1588291200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 902,
#    'AKUMULASI_KASUS': 1169,
#    'AKUMULASI_MENINGGAL': 100,
#    'AKUMULASI_SEMBUH': 167,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 36,
#    'MENINGGAL': 1,
#    'SEMBUH': 2,
#    'tanggal': 1588377600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 908,
#    'AKUMULASI_KASUS': 1183,
#    'AKUMULASI_MENINGGAL': 101,
#    'AKUMULASI_SEMBUH': 174,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 14,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1588464000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1080,
#    'AKUMULASI_KASUS': 1365,
#    'AKUMULASI_MENINGGAL': 104,
#    'AKUMULASI_SEMBUH': 181,
#    'DIRAWAT_OR_ISOLASI': 172,
#    'KASUS': 182,
#    'MENINGGAL': 3,
#    'SEMBUH': 7,
#    'tanggal': 1588550400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1121,
#    'AKUMULASI_KASUS': 1417,
#    'AKUMULASI_MENINGGAL': 105,
#    'AKUMULASI_SEMBUH': 191,
#    'DIRAWAT_OR_ISOLASI': 41,
#    'KASUS': 52,
#    'MENINGGAL': 1,
#    'SEMBUH': 10,
#    'tanggal': 1588636800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1131,
#    'AKUMULASI_KASUS': 1438,
#    'AKUMULASI_MENINGGAL': 108,
#    'AKUMULASI_SEMBUH': 199,
#    'DIRAWAT_OR_ISOLASI': 10,
#    'KASUS': 21,
#    'MENINGGAL': 3,
#    'SEMBUH': 8,
#    'tanggal': 1588723200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1178,
#    'AKUMULASI_KASUS': 1491,
#    'AKUMULASI_MENINGGAL': 108,
#    'AKUMULASI_SEMBUH': 205,
#    'DIRAWAT_OR_ISOLASI': 47,
#    'KASUS': 53,
#    'MENINGGAL': 0,
#    'SEMBUH': 6,
#    'tanggal': 1588809600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1206,
#    'AKUMULASI_KASUS': 1521,
#    'AKUMULASI_MENINGGAL': 110,
#    'AKUMULASI_SEMBUH': 205,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 30,
#    'MENINGGAL': 2,
#    'SEMBUH': 0,
#    'tanggal': 1588896000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1213,
#    'AKUMULASI_KASUS': 1550,
#    'AKUMULASI_MENINGGAL': 113,
#    'AKUMULASI_SEMBUH': 224,
#    'DIRAWAT_OR_ISOLASI': 7,
#    'KASUS': 29,
#    'MENINGGAL': 3,
#    'SEMBUH': 19,
#    'tanggal': 1588982400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1211,
#    'AKUMULASI_KASUS': 1550,
#    'AKUMULASI_MENINGGAL': 113,
#    'AKUMULASI_SEMBUH': 226,
#    'DIRAWAT_OR_ISOLASI': -2,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1589068800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1251,
#    'AKUMULASI_KASUS': 1604,
#    'AKUMULASI_MENINGGAL': 116,
#    'AKUMULASI_SEMBUH': 237,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 54,
#    'MENINGGAL': 3,
#    'SEMBUH': 11,
#    'tanggal': 1589155200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1301,
#    'AKUMULASI_KASUS': 1658,
#    'AKUMULASI_MENINGGAL': 116,
#    'AKUMULASI_SEMBUH': 241,
#    'DIRAWAT_OR_ISOLASI': 50,
#    'KASUS': 54,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1589241600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1282,
#    'AKUMULASI_KASUS': 1666,
#    'AKUMULASI_MENINGGAL': 116,
#    'AKUMULASI_SEMBUH': 268,
#    'DIRAWAT_OR_ISOLASI': -19,
#    'KASUS': 8,
#    'MENINGGAL': 0,
#    'SEMBUH': 27,
#    'tanggal': 1589328000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1285,
#    'AKUMULASI_KASUS': 1677,
#    'AKUMULASI_MENINGGAL': 117,
#    'AKUMULASI_SEMBUH': 275,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 11,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1589414400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1299,
#    'AKUMULASI_KASUS': 1710,
#    'AKUMULASI_MENINGGAL': 118,
#    'AKUMULASI_SEMBUH': 293,
#    'DIRAWAT_OR_ISOLASI': 14,
#    'KASUS': 33,
#    'MENINGGAL': 1,
#    'SEMBUH': 18,
#    'tanggal': 1589500800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1320,
#    'AKUMULASI_KASUS': 1734,
#    'AKUMULASI_MENINGGAL': 118,
#    'AKUMULASI_SEMBUH': 296,
#    'DIRAWAT_OR_ISOLASI': 21,
#    'KASUS': 24,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1589587200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1292,
#    'AKUMULASI_KASUS': 1766,
#    'AKUMULASI_MENINGGAL': 121,
#    'AKUMULASI_SEMBUH': 353,
#    'DIRAWAT_OR_ISOLASI': -28,
#    'KASUS': 32,
#    'MENINGGAL': 3,
#    'SEMBUH': 57,
#    'tanggal': 1589673600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1231,
#    'AKUMULASI_KASUS': 1788,
#    'AKUMULASI_MENINGGAL': 130,
#    'AKUMULASI_SEMBUH': 427,
#    'DIRAWAT_OR_ISOLASI': -61,
#    'KASUS': 22,
#    'MENINGGAL': 9,
#    'SEMBUH': 74,
#    'tanggal': 1589760000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1240,
#    'AKUMULASI_KASUS': 1812,
#    'AKUMULASI_MENINGGAL': 131,
#    'AKUMULASI_SEMBUH': 441,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 24,
#    'MENINGGAL': 1,
#    'SEMBUH': 14,
#    'tanggal': 1589846400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1381,
#    'AKUMULASI_KASUS': 1955,
#    'AKUMULASI_MENINGGAL': 131,
#    'AKUMULASI_SEMBUH': 443,
#    'DIRAWAT_OR_ISOLASI': 141,
#    'KASUS': 143,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1589932800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1438,
#    'AKUMULASI_KASUS': 2023,
#    'AKUMULASI_MENINGGAL': 131,
#    'AKUMULASI_SEMBUH': 454,
#    'DIRAWAT_OR_ISOLASI': 57,
#    'KASUS': 68,
#    'MENINGGAL': 0,
#    'SEMBUH': 11,
#    'tanggal': 1590019200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1461,
#    'AKUMULASI_KASUS': 2061,
#    'AKUMULASI_MENINGGAL': 133,
#    'AKUMULASI_SEMBUH': 467,
#    'DIRAWAT_OR_ISOLASI': 23,
#    'KASUS': 38,
#    'MENINGGAL': 2,
#    'SEMBUH': 13,
#    'tanggal': 1590105600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1474,
#    'AKUMULASI_KASUS': 2116,
#    'AKUMULASI_MENINGGAL': 135,
#    'AKUMULASI_SEMBUH': 507,
#    'DIRAWAT_OR_ISOLASI': 13,
#    'KASUS': 55,
#    'MENINGGAL': 2,
#    'SEMBUH': 40,
#    'tanggal': 1590192000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1511,
#    'AKUMULASI_KASUS': 2165,
#    'AKUMULASI_MENINGGAL': 136,
#    'AKUMULASI_SEMBUH': 518,
#    'DIRAWAT_OR_ISOLASI': 37,
#    'KASUS': 49,
#    'MENINGGAL': 1,
#    'SEMBUH': 11,
#    'tanggal': 1590278400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1525,
#    'AKUMULASI_KASUS': 2183,
#    'AKUMULASI_MENINGGAL': 136,
#    'AKUMULASI_SEMBUH': 522,
#    'DIRAWAT_OR_ISOLASI': 14,
#    'KASUS': 18,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1590364800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1510,
#    'AKUMULASI_KASUS': 2198,
#    'AKUMULASI_MENINGGAL': 145,
#    'AKUMULASI_SEMBUH': 543,
#    'DIRAWAT_OR_ISOLASI': -15,
#    'KASUS': 15,
#    'MENINGGAL': 9,
#    'SEMBUH': 21,
#    'tanggal': 1590451200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1498,
#    'AKUMULASI_KASUS': 2223,
#    'AKUMULASI_MENINGGAL': 150,
#    'AKUMULASI_SEMBUH': 575,
#    'DIRAWAT_OR_ISOLASI': -12,
#    'KASUS': 25,
#    'MENINGGAL': 5,
#    'SEMBUH': 32,
#    'tanggal': 1590537600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1479,
#    'AKUMULASI_KASUS': 2249,
#    'AKUMULASI_MENINGGAL': 150,
#    'AKUMULASI_SEMBUH': 620,
#    'DIRAWAT_OR_ISOLASI': -19,
#    'KASUS': 26,
#    'MENINGGAL': 0,
#    'SEMBUH': 45,
#    'tanggal': 1590624000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1512,
#    'AKUMULASI_KASUS': 2289,
#    'AKUMULASI_MENINGGAL': 151,
#    'AKUMULASI_SEMBUH': 626,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 40,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1590710400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1498,
#    'AKUMULASI_KASUS': 2309,
#    'AKUMULASI_MENINGGAL': 153,
#    'AKUMULASI_SEMBUH': 658,
#    'DIRAWAT_OR_ISOLASI': -14,
#    'KASUS': 20,
#    'MENINGGAL': 2,
#    'SEMBUH': 32,
#    'tanggal': 1590796800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1528,
#    'AKUMULASI_KASUS': 2347,
#    'AKUMULASI_MENINGGAL': 153,
#    'AKUMULASI_SEMBUH': 666,
#    'DIRAWAT_OR_ISOLASI': 30,
#    'KASUS': 38,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1590883200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1561,
#    'AKUMULASI_KASUS': 2388,
#    'AKUMULASI_MENINGGAL': 153,
#    'AKUMULASI_SEMBUH': 674,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 41,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1590969600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1536,
#    'AKUMULASI_KASUS': 2406,
#    'AKUMULASI_MENINGGAL': 160,
#    'AKUMULASI_SEMBUH': 710,
#    'DIRAWAT_OR_ISOLASI': -25,
#    'KASUS': 18,
#    'MENINGGAL': 7,
#    'SEMBUH': 36,
#    'tanggal': 1591056000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1482,
#    'AKUMULASI_KASUS': 2410,
#    'AKUMULASI_MENINGGAL': 163,
#    'AKUMULASI_SEMBUH': 765,
#    'DIRAWAT_OR_ISOLASI': -54,
#    'KASUS': 4,
#    'MENINGGAL': 3,
#    'SEMBUH': 55,
#    'tanggal': 1591142400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1469,
#    'AKUMULASI_KASUS': 2418,
#    'AKUMULASI_MENINGGAL': 164,
#    'AKUMULASI_SEMBUH': 785,
#    'DIRAWAT_OR_ISOLASI': -13,
#    'KASUS': 8,
#    'MENINGGAL': 1,
#    'SEMBUH': 20,
#    'tanggal': 1591228800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1434,
#    'AKUMULASI_KASUS': 2433,
#    'AKUMULASI_MENINGGAL': 167,
#    'AKUMULASI_SEMBUH': 832,
#    'DIRAWAT_OR_ISOLASI': -35,
#    'KASUS': 15,
#    'MENINGGAL': 3,
#    'SEMBUH': 47,
#    'tanggal': 1591315200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1431,
#    'AKUMULASI_KASUS': 2446,
#    'AKUMULASI_MENINGGAL': 167,
#    'AKUMULASI_SEMBUH': 848,
#    'DIRAWAT_OR_ISOLASI': -3,
#    'KASUS': 13,
#    'MENINGGAL': 0,
#    'SEMBUH': 16,
#    'tanggal': 1591401600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1359,
#    'AKUMULASI_KASUS': 2480,
#    'AKUMULASI_MENINGGAL': 167,
#    'AKUMULASI_SEMBUH': 954,
#    'DIRAWAT_OR_ISOLASI': -72,
#    'KASUS': 34,
#    'MENINGGAL': 0,
#    'SEMBUH': 106,
#    'tanggal': 1591488000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1312,
#    'AKUMULASI_KASUS': 2504,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1022,
#    'DIRAWAT_OR_ISOLASI': -47,
#    'KASUS': 24,
#    'MENINGGAL': 3,
#    'SEMBUH': 68,
#    'tanggal': 1591574400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1329,
#    'AKUMULASI_KASUS': 2533,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1034,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 29,
#    'MENINGGAL': 0,
#    'SEMBUH': 12,
#    'tanggal': 1591660800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1340,
#    'AKUMULASI_KASUS': 2582,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1072,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 49,
#    'MENINGGAL': 0,
#    'SEMBUH': 38,
#    'tanggal': 1591747200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1367,
#    'AKUMULASI_KASUS': 2629,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1092,
#    'DIRAWAT_OR_ISOLASI': 27,
#    'KASUS': 47,
#    'MENINGGAL': 0,
#    'SEMBUH': 20,
#    'tanggal': 1591833600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1335,
#    'AKUMULASI_KASUS': 2644,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1139,
#    'DIRAWAT_OR_ISOLASI': -32,
#    'KASUS': 15,
#    'MENINGGAL': 0,
#    'SEMBUH': 47,
#    'tanggal': 1591920000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1311,
#    'AKUMULASI_KASUS': 2656,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1175,
#    'DIRAWAT_OR_ISOLASI': -24,
#    'KASUS': 12,
#    'MENINGGAL': 0,
#    'SEMBUH': 36,
#    'tanggal': 1592006400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1287,
#    'AKUMULASI_KASUS': 2671,
#    'AKUMULASI_MENINGGAL': 170,
#    'AKUMULASI_SEMBUH': 1214,
#    'DIRAWAT_OR_ISOLASI': -24,
#    'KASUS': 15,
#    'MENINGGAL': 0,
#    'SEMBUH': 39,
#    'tanggal': 1592092800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1303,
#    'AKUMULASI_KASUS': 2695,
#    'AKUMULASI_MENINGGAL': 171,
#    'AKUMULASI_SEMBUH': 1221,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 24,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1592179200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1328,
#    'AKUMULASI_KASUS': 2732,
#    'AKUMULASI_MENINGGAL': 171,
#    'AKUMULASI_SEMBUH': 1233,
#    'DIRAWAT_OR_ISOLASI': 25,
#    'KASUS': 37,
#    'MENINGGAL': 0,
#    'SEMBUH': 12,
#    'tanggal': 1592265600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1336,
#    'AKUMULASI_KASUS': 2775,
#    'AKUMULASI_MENINGGAL': 178,
#    'AKUMULASI_SEMBUH': 1261,
#    'DIRAWAT_OR_ISOLASI': 8,
#    'KASUS': 43,
#    'MENINGGAL': 7,
#    'SEMBUH': 28,
#    'tanggal': 1592352000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1331,
#    'AKUMULASI_KASUS': 2826,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1315,
#    'DIRAWAT_OR_ISOLASI': -5,
#    'KASUS': 51,
#    'MENINGGAL': 2,
#    'SEMBUH': 54,
#    'tanggal': 1592438400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1365,
#    'AKUMULASI_KASUS': 2889,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1344,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 63,
#    'MENINGGAL': 0,
#    'SEMBUH': 29,
#    'tanggal': 1592524800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1383,
#    'AKUMULASI_KASUS': 2908,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1345,
#    'DIRAWAT_OR_ISOLASI': 18,
#    'KASUS': 19,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1592611200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1403,
#    'AKUMULASI_KASUS': 2930,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1347,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 22,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1592697600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1397,
#    'AKUMULASI_KASUS': 2948,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1371,
#    'DIRAWAT_OR_ISOLASI': -6,
#    'KASUS': 18,
#    'MENINGGAL': 0,
#    'SEMBUH': 24,
#    'tanggal': 1592784000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1399,
#    'AKUMULASI_KASUS': 2980,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1401,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 30,
#    'tanggal': 1592870400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1437,
#    'AKUMULASI_KASUS': 3026,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1409,
#    'DIRAWAT_OR_ISOLASI': 38,
#    'KASUS': 46,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1592956800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1419,
#    'AKUMULASI_KASUS': 3067,
#    'AKUMULASI_MENINGGAL': 182,
#    'AKUMULASI_SEMBUH': 1466,
#    'DIRAWAT_OR_ISOLASI': -18,
#    'KASUS': 41,
#    'MENINGGAL': 2,
#    'SEMBUH': 57,
#    'tanggal': 1593043200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1343,
#    'AKUMULASI_KASUS': 3102,
#    'AKUMULASI_MENINGGAL': 184,
#    'AKUMULASI_SEMBUH': 1575,
#    'DIRAWAT_OR_ISOLASI': -76,
#    'KASUS': 35,
#    'MENINGGAL': 2,
#    'SEMBUH': 109,
#    'tanggal': 1593129600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1378,
#    'AKUMULASI_KASUS': 3151,
#    'AKUMULASI_MENINGGAL': 184,
#    'AKUMULASI_SEMBUH': 1589,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 49,
#    'MENINGGAL': 0,
#    'SEMBUH': 14,
#    'tanggal': 1593216000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1395,
#    'AKUMULASI_KASUS': 3177,
#    'AKUMULASI_MENINGGAL': 184,
#    'AKUMULASI_SEMBUH': 1598,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 26,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1593302400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1434,
#    'AKUMULASI_KASUS': 3219,
#    'AKUMULASI_MENINGGAL': 184,
#    'AKUMULASI_SEMBUH': 1601,
#    'DIRAWAT_OR_ISOLASI': 39,
#    'KASUS': 42,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1593388800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1424,
#    'AKUMULASI_KASUS': 3294,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1685,
#    'DIRAWAT_OR_ISOLASI': -10,
#    'KASUS': 75,
#    'MENINGGAL': 1,
#    'SEMBUH': 84,
#    'tanggal': 1593475200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1467,
#    'AKUMULASI_KASUS': 3352,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1700,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 58,
#    'MENINGGAL': 0,
#    'SEMBUH': 15,
#    'tanggal': 1593561600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1487,
#    'AKUMULASI_KASUS': 3417,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1745,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 65,
#    'MENINGGAL': 0,
#    'SEMBUH': 45,
#    'tanggal': 1593648000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1515,
#    'AKUMULASI_KASUS': 3449,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1749,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1593734400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1578,
#    'AKUMULASI_KASUS': 3535,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1772,
#    'DIRAWAT_OR_ISOLASI': 63,
#    'KASUS': 86,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1593820800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1670,
#    'AKUMULASI_KASUS': 3643,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1788,
#    'DIRAWAT_OR_ISOLASI': 92,
#    'KASUS': 108,
#    'MENINGGAL': 0,
#    'SEMBUH': 16,
#    'tanggal': 1593907200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1776,
#    'AKUMULASI_KASUS': 3772,
#    'AKUMULASI_MENINGGAL': 186,
#    'AKUMULASI_SEMBUH': 1810,
#    'DIRAWAT_OR_ISOLASI': 106,
#    'KASUS': 129,
#    'MENINGGAL': 1,
#    'SEMBUH': 22,
#    'tanggal': 1593993600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1811,
#    'AKUMULASI_KASUS': 3853,
#    'AKUMULASI_MENINGGAL': 188,
#    'AKUMULASI_SEMBUH': 1854,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 81,
#    'MENINGGAL': 2,
#    'SEMBUH': 44,
#    'tanggal': 1594080000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1879,
#    'AKUMULASI_KASUS': 3948,
#    'AKUMULASI_MENINGGAL': 190,
#    'AKUMULASI_SEMBUH': 1879,
#    'DIRAWAT_OR_ISOLASI': 68,
#    'KASUS': 95,
#    'MENINGGAL': 2,
#    'SEMBUH': 25,
#    'tanggal': 1594166400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2811,
#    'AKUMULASI_KASUS': 4912,
#    'AKUMULASI_MENINGGAL': 194,
#    'AKUMULASI_SEMBUH': 1907,
#    'DIRAWAT_OR_ISOLASI': 932,
#    'KASUS': 964,
#    'MENINGGAL': 4,
#    'SEMBUH': 28,
#    'tanggal': 1594252800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2886,
#    'AKUMULASI_KASUS': 5020,
#    'AKUMULASI_MENINGGAL': 194,
#    'AKUMULASI_SEMBUH': 1940,
#    'DIRAWAT_OR_ISOLASI': 75,
#    'KASUS': 108,
#    'MENINGGAL': 0,
#    'SEMBUH': 33,
#    'tanggal': 1594339200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2929,
#    'AKUMULASI_KASUS': 5093,
#    'AKUMULASI_MENINGGAL': 195,
#    'AKUMULASI_SEMBUH': 1969,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 73,
#    'MENINGGAL': 1,
#    'SEMBUH': 29,
#    'tanggal': 1594425600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2964,
#    'AKUMULASI_KASUS': 5137,
#    'AKUMULASI_MENINGGAL': 195,
#    'AKUMULASI_SEMBUH': 1978,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 44,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1594512000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3032,
#    'AKUMULASI_KASUS': 5224,
#    'AKUMULASI_MENINGGAL': 195,
#    'AKUMULASI_SEMBUH': 1997,
#    'DIRAWAT_OR_ISOLASI': 68,
#    'KASUS': 87,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1594598400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3074,
#    'AKUMULASI_KASUS': 5301,
#    'AKUMULASI_MENINGGAL': 196,
#    'AKUMULASI_SEMBUH': 2031,
#    'DIRAWAT_OR_ISOLASI': 42,
#    'KASUS': 77,
#    'MENINGGAL': 1,
#    'SEMBUH': 34,
#    'tanggal': 1594684800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3002,
#    'AKUMULASI_KASUS': 5375,
#    'AKUMULASI_MENINGGAL': 197,
#    'AKUMULASI_SEMBUH': 2176,
#    'DIRAWAT_OR_ISOLASI': -72,
#    'KASUS': 74,
#    'MENINGGAL': 1,
#    'SEMBUH': 145,
#    'tanggal': 1594771200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3024,
#    'AKUMULASI_KASUS': 5415,
#    'AKUMULASI_MENINGGAL': 197,
#    'AKUMULASI_SEMBUH': 2194,
#    'DIRAWAT_OR_ISOLASI': 22,
#    'KASUS': 40,
#    'MENINGGAL': 0,
#    'SEMBUH': 18,
#    'tanggal': 1594857600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3041,
#    'AKUMULASI_KASUS': 5466,
#    'AKUMULASI_MENINGGAL': 198,
#    'AKUMULASI_SEMBUH': 2227,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 51,
#    'MENINGGAL': 1,
#    'SEMBUH': 33,
#    'tanggal': 1594944000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3080,
#    'AKUMULASI_KASUS': 5524,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2245,
#    'DIRAWAT_OR_ISOLASI': 39,
#    'KASUS': 58,
#    'MENINGGAL': 1,
#    'SEMBUH': 18,
#    'tanggal': 1595030400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3100,
#    'AKUMULASI_KASUS': 5548,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2249,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 24,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1595116800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3063,
#    'AKUMULASI_KASUS': 5607,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2345,
#    'DIRAWAT_OR_ISOLASI': -37,
#    'KASUS': 59,
#    'MENINGGAL': 0,
#    'SEMBUH': 96,
#    'tanggal': 1595203200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3092,
#    'AKUMULASI_KASUS': 5672,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 2377,
#    'DIRAWAT_OR_ISOLASI': 29,
#    'KASUS': 65,
#    'MENINGGAL': 4,
#    'SEMBUH': 32,
#    'tanggal': 1595289600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3101,
#    'AKUMULASI_KASUS': 5704,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 2400,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1595376000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3150,
#    'AKUMULASI_KASUS': 5767,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 2413,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 63,
#    'MENINGGAL': 1,
#    'SEMBUH': 13,
#    'tanggal': 1595462400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3220,
#    'AKUMULASI_KASUS': 5856,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 2432,
#    'DIRAWAT_OR_ISOLASI': 70,
#    'KASUS': 89,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1595548800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3260,
#    'AKUMULASI_KASUS': 5928,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 2464,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 72,
#    'MENINGGAL': 0,
#    'SEMBUH': 32,
#    'tanggal': 1595635200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3287,
#    'AKUMULASI_KASUS': 5978,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 2487,
#    'DIRAWAT_OR_ISOLASI': 27,
#    'KASUS': 50,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1595721600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2938,
#    'AKUMULASI_KASUS': 6035,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 2893,
#    'DIRAWAT_OR_ISOLASI': -349,
#    'KASUS': 57,
#    'MENINGGAL': 0,
#    'SEMBUH': 406,
#    'tanggal': 1595808000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2464,
#    'AKUMULASI_KASUS': 6167,
#    'AKUMULASI_MENINGGAL': 204,
#    'AKUMULASI_SEMBUH': 3499,
#    'DIRAWAT_OR_ISOLASI': -474,
#    'KASUS': 132,
#    'MENINGGAL': 0,
#    'SEMBUH': 606,
#    'tanggal': 1595894400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2511,
#    'AKUMULASI_KASUS': 6264,
#    'AKUMULASI_MENINGGAL': 206,
#    'AKUMULASI_SEMBUH': 3547,
#    'DIRAWAT_OR_ISOLASI': 47,
#    'KASUS': 97,
#    'MENINGGAL': 2,
#    'SEMBUH': 48,
#    'tanggal': 1595980800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2317,
#    'AKUMULASI_KASUS': 6405,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 3880,
#    'DIRAWAT_OR_ISOLASI': -194,
#    'KASUS': 141,
#    'MENINGGAL': 2,
#    'SEMBUH': 333,
#    'tanggal': 1596067200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2369,
#    'AKUMULASI_KASUS': 6474,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 3897,
#    'DIRAWAT_OR_ISOLASI': 52,
#    'KASUS': 69,
#    'MENINGGAL': 0,
#    'SEMBUH': 17,
#    'tanggal': 1596153600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2409,
#    'AKUMULASI_KASUS': 6533,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 3916,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 59,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1596240000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2459,
#    'AKUMULASI_KASUS': 6590,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 3923,
#    'DIRAWAT_OR_ISOLASI': 50,
#    'KASUS': 57,
#    'MENINGGAL': 0,
#    'SEMBUH': 7,
#    'tanggal': 1596326400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2465,
#    'AKUMULASI_KASUS': 6643,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 3970,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 53,
#    'MENINGGAL': 0,
#    'SEMBUH': 47,
#    'tanggal': 1596412800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2383,
#    'AKUMULASI_KASUS': 6736,
#    'AKUMULASI_MENINGGAL': 213,
#    'AKUMULASI_SEMBUH': 4140,
#    'DIRAWAT_OR_ISOLASI': -82,
#    'KASUS': 93,
#    'MENINGGAL': 5,
#    'SEMBUH': 170,
#    'tanggal': 1596499200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2498,
#    'AKUMULASI_KASUS': 6860,
#    'AKUMULASI_MENINGGAL': 213,
#    'AKUMULASI_SEMBUH': 4149,
#    'DIRAWAT_OR_ISOLASI': 115,
#    'KASUS': 124,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1596585600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2547,
#    'AKUMULASI_KASUS': 6942,
#    'AKUMULASI_MENINGGAL': 214,
#    'AKUMULASI_SEMBUH': 4181,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 82,
#    'MENINGGAL': 1,
#    'SEMBUH': 32,
#    'tanggal': 1596672000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2632,
#    'AKUMULASI_KASUS': 7093,
#    'AKUMULASI_MENINGGAL': 218,
#    'AKUMULASI_SEMBUH': 4243,
#    'DIRAWAT_OR_ISOLASI': 85,
#    'KASUS': 151,
#    'MENINGGAL': 4,
#    'SEMBUH': 62,
#    'tanggal': 1596758400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2830,
#    'AKUMULASI_KASUS': 7334,
#    'AKUMULASI_MENINGGAL': 221,
#    'AKUMULASI_SEMBUH': 4283,
#    'DIRAWAT_OR_ISOLASI': 198,
#    'KASUS': 241,
#    'MENINGGAL': 3,
#    'SEMBUH': 40,
#    'tanggal': 1596844800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2936,
#    'AKUMULASI_KASUS': 7510,
#    'AKUMULASI_MENINGGAL': 225,
#    'AKUMULASI_SEMBUH': 4349,
#    'DIRAWAT_OR_ISOLASI': 106,
#    'KASUS': 176,
#    'MENINGGAL': 4,
#    'SEMBUH': 66,
#    'tanggal': 1596931200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2942,
#    'AKUMULASI_KASUS': 7543,
#    'AKUMULASI_MENINGGAL': 225,
#    'AKUMULASI_SEMBUH': 4376,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 33,
#    'MENINGGAL': 0,
#    'SEMBUH': 27,
#    'tanggal': 1597017600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2991,
#    'AKUMULASI_KASUS': 7635,
#    'AKUMULASI_MENINGGAL': 229,
#    'AKUMULASI_SEMBUH': 4415,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 92,
#    'MENINGGAL': 4,
#    'SEMBUH': 39,
#    'tanggal': 1597104000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3026,
#    'AKUMULASI_KASUS': 7741,
#    'AKUMULASI_MENINGGAL': 230,
#    'AKUMULASI_SEMBUH': 4485,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 106,
#    'MENINGGAL': 1,
#    'SEMBUH': 70,
#    'tanggal': 1597190400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3118,
#    'AKUMULASI_KASUS': 7851,
#    'AKUMULASI_MENINGGAL': 231,
#    'AKUMULASI_SEMBUH': 4502,
#    'DIRAWAT_OR_ISOLASI': 92,
#    'KASUS': 110,
#    'MENINGGAL': 1,
#    'SEMBUH': 17,
#    'tanggal': 1597276800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3458,
#    'AKUMULASI_KASUS': 8213,
#    'AKUMULASI_MENINGGAL': 232,
#    'AKUMULASI_SEMBUH': 4523,
#    'DIRAWAT_OR_ISOLASI': 340,
#    'KASUS': 362,
#    'MENINGGAL': 1,
#    'SEMBUH': 21,
#    'tanggal': 1597363200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3649,
#    'AKUMULASI_KASUS': 8440,
#    'AKUMULASI_MENINGGAL': 232,
#    'AKUMULASI_SEMBUH': 4559,
#    'DIRAWAT_OR_ISOLASI': 191,
#    'KASUS': 227,
#    'MENINGGAL': 0,
#    'SEMBUH': 36,
#    'tanggal': 1597449600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3684,
# ...
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 22843,
#    'AKUMULASI_KASUS': 328942,
#    'AKUMULASI_MENINGGAL': 4422,
#    'AKUMULASI_SEMBUH': 301677,
#    'DIRAWAT_OR_ISOLASI': 523,
#    'KASUS': 1243,
#    'MENINGGAL': 9,
#    'SEMBUH': 711,
#    'tanggal': 1623542400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 22602,
#    'AKUMULASI_KASUS': 330474,
#    'AKUMULASI_MENINGGAL': 4438,
#    'AKUMULASI_SEMBUH': 303434,
#    'DIRAWAT_OR_ISOLASI': -241,
#    'KASUS': 1532,
#    'MENINGGAL': 16,
#    'SEMBUH': 1757,
#    'tanggal': 1623628800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 23098,
#    'AKUMULASI_KASUS': 332267,
#    'AKUMULASI_MENINGGAL': 4449,
#    'AKUMULASI_SEMBUH': 304720,
#    'DIRAWAT_OR_ISOLASI': 496,
#    'KASUS': 1793,
#    'MENINGGAL': 11,
#    'SEMBUH': 1286,
#    'tanggal': 1623715200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 24171,
#    'AKUMULASI_KASUS': 334866,
#    'AKUMULASI_MENINGGAL': 4464,
#    'AKUMULASI_SEMBUH': 306231,
#    'DIRAWAT_OR_ISOLASI': 1073,
#    'KASUS': 2599,
#    'MENINGGAL': 15,
#    'SEMBUH': 1511,
#    'tanggal': 1623801600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 25849,
#    'AKUMULASI_KASUS': 337666,
#    'AKUMULASI_MENINGGAL': 4481,
#    'AKUMULASI_SEMBUH': 307336,
#    'DIRAWAT_OR_ISOLASI': 1678,
#    'KASUS': 2800,
#    'MENINGGAL': 17,
#    'SEMBUH': 1105,
#    'tanggal': 1623888000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27293,
#    'AKUMULASI_KASUS': 340457,
#    'AKUMULASI_MENINGGAL': 4529,
#    'AKUMULASI_SEMBUH': 308635,
#    'DIRAWAT_OR_ISOLASI': 1444,
#    'KASUS': 2791,
#    'MENINGGAL': 48,
#    'SEMBUH': 1299,
#    'tanggal': 1623974400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 28337,
#    'AKUMULASI_KASUS': 342561,
#    'AKUMULASI_MENINGGAL': 4544,
#    'AKUMULASI_SEMBUH': 309680,
#    'DIRAWAT_OR_ISOLASI': 1044,
#    'KASUS': 2104,
#    'MENINGGAL': 15,
#    'SEMBUH': 1045,
#    'tanggal': 1624060800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 29279,
#    'AKUMULASI_KASUS': 344570,
#    'AKUMULASI_MENINGGAL': 4606,
#    'AKUMULASI_SEMBUH': 310685,
#    'DIRAWAT_OR_ISOLASI': 942,
#    'KASUS': 2009,
#    'MENINGGAL': 62,
#    'SEMBUH': 1005,
#    'tanggal': 1624147200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 30718,
#    'AKUMULASI_KASUS': 347289,
#    'AKUMULASI_MENINGGAL': 4634,
#    'AKUMULASI_SEMBUH': 311937,
#    'DIRAWAT_OR_ISOLASI': 1439,
#    'KASUS': 2719,
#    'MENINGGAL': 28,
#    'SEMBUH': 1252,
#    'tanggal': 1624233600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 33086,
#    'AKUMULASI_KASUS': 350721,
#    'AKUMULASI_MENINGGAL': 4703,
#    'AKUMULASI_SEMBUH': 312932,
#    'DIRAWAT_OR_ISOLASI': 2368,
#    'KASUS': 3432,
#    'MENINGGAL': 69,
#    'SEMBUH': 995,
#    'tanggal': 1624320000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 34915,
#    'AKUMULASI_KASUS': 353632,
#    'AKUMULASI_MENINGGAL': 4741,
#    'AKUMULASI_SEMBUH': 313976,
#    'DIRAWAT_OR_ISOLASI': 1829,
#    'KASUS': 2911,
#    'MENINGGAL': 38,
#    'SEMBUH': 1044,
#    'tanggal': 1624406400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 36218,
#    'AKUMULASI_KASUS': 356685,
#    'AKUMULASI_MENINGGAL': 4825,
#    'AKUMULASI_SEMBUH': 315642,
#    'DIRAWAT_OR_ISOLASI': 1303,
#    'KASUS': 3053,
#    'MENINGGAL': 84,
#    'SEMBUH': 1666,
#    'tanggal': 1624492800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 38720,
#    'AKUMULASI_KASUS': 360531,
#    'AKUMULASI_MENINGGAL': 4909,
#    'AKUMULASI_SEMBUH': 316902,
#    'DIRAWAT_OR_ISOLASI': 2502,
#    'KASUS': 3846,
#    'MENINGGAL': 84,
#    'SEMBUH': 1260,
#    'tanggal': 1624579200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 41236,
#    'AKUMULASI_KASUS': 364318,
#    'AKUMULASI_MENINGGAL': 4984,
#    'AKUMULASI_SEMBUH': 318098,
#    'DIRAWAT_OR_ISOLASI': 2516,
#    'KASUS': 3787,
#    'MENINGGAL': 75,
#    'SEMBUH': 1196,
#    'tanggal': 1624665600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 43869,
#    'AKUMULASI_KASUS': 368306,
#    'AKUMULASI_MENINGGAL': 5078,
#    'AKUMULASI_SEMBUH': 319359,
#    'DIRAWAT_OR_ISOLASI': 2633,
#    'KASUS': 3988,
#    'MENINGGAL': 94,
#    'SEMBUH': 1261,
#    'tanggal': 1624752000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 47377,
#    'AKUMULASI_KASUS': 373077,
#    'AKUMULASI_MENINGGAL': 5151,
#    'AKUMULASI_SEMBUH': 320549,
#    'DIRAWAT_OR_ISOLASI': 3508,
#    'KASUS': 4771,
#    'MENINGGAL': 73,
#    'SEMBUH': 1190,
#    'tanggal': 1624838400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 50034,
#    'AKUMULASI_KASUS': 376985,
#    'AKUMULASI_MENINGGAL': 5263,
#    'AKUMULASI_SEMBUH': 321688,
#    'DIRAWAT_OR_ISOLASI': 2657,
#    'KASUS': 3908,
#    'MENINGGAL': 112,
#    'SEMBUH': 1139,
#    'tanggal': 1624924800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 52210,
#    'AKUMULASI_KASUS': 381458,
#    'AKUMULASI_MENINGGAL': 5354,
#    'AKUMULASI_SEMBUH': 323894,
#    'DIRAWAT_OR_ISOLASI': 2176,
#    'KASUS': 4473,
#    'MENINGGAL': 91,
#    'SEMBUH': 2206,
#    'tanggal': 1625011200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 57027,
#    'AKUMULASI_KASUS': 387637,
#    'AKUMULASI_MENINGGAL': 5418,
#    'AKUMULASI_SEMBUH': 325192,
#    'DIRAWAT_OR_ISOLASI': 4817,
#    'KASUS': 6179,
#    'MENINGGAL': 64,
#    'SEMBUH': 1298,
#    'tanggal': 1625097600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 60316,
#    'AKUMULASI_KASUS': 392557,
#    'AKUMULASI_MENINGGAL': 5455,
#    'AKUMULASI_SEMBUH': 326786,
#    'DIRAWAT_OR_ISOLASI': 3289,
#    'KASUS': 4920,
#    'MENINGGAL': 37,
#    'SEMBUH': 1594,
#    'tanggal': 1625184000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 63398,
#    'AKUMULASI_KASUS': 397950,
#    'AKUMULASI_MENINGGAL': 5492,
#    'AKUMULASI_SEMBUH': 329060,
#    'DIRAWAT_OR_ISOLASI': 3082,
#    'KASUS': 5393,
#    'MENINGGAL': 37,
#    'SEMBUH': 2274,
#    'tanggal': 1625270400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 65666,
#    'AKUMULASI_KASUS': 402408,
#    'AKUMULASI_MENINGGAL': 5558,
#    'AKUMULASI_SEMBUH': 331184,
#    'DIRAWAT_OR_ISOLASI': 2268,
#    'KASUS': 4458,
#    'MENINGGAL': 66,
#    'SEMBUH': 2124,
#    'tanggal': 1625356800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 70933,
#    'AKUMULASI_KASUS': 409379,
#    'AKUMULASI_MENINGGAL': 5596,
#    'AKUMULASI_SEMBUH': 332850,
#    'DIRAWAT_OR_ISOLASI': 5267,
#    'KASUS': 6971,
#    'MENINGGAL': 38,
#    'SEMBUH': 1666,
#    'tanggal': 1625443200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 74600,
#    'AKUMULASI_KASUS': 416618,
#    'AKUMULASI_MENINGGAL': 5645,
#    'AKUMULASI_SEMBUH': 336373,
#    'DIRAWAT_OR_ISOLASI': 3667,
#    'KASUS': 7239,
#    'MENINGGAL': 49,
#    'SEMBUH': 3523,
#    'tanggal': 1625529600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 79408,
#    'AKUMULASI_KASUS': 425209,
#    'AKUMULASI_MENINGGAL': 5713,
#    'AKUMULASI_SEMBUH': 340088,
#    'DIRAWAT_OR_ISOLASI': 4808,
#    'KASUS': 8591,
#    'MENINGGAL': 68,
#    'SEMBUH': 3715,
#    'tanggal': 1625616000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 83787,
#    'AKUMULASI_KASUS': 432981,
#    'AKUMULASI_MENINGGAL': 5849,
#    'AKUMULASI_SEMBUH': 343345,
#    'DIRAWAT_OR_ISOLASI': 4379,
#    'KASUS': 7772,
#    'MENINGGAL': 136,
#    'SEMBUH': 3257,
#    'tanggal': 1625702400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 86061,
#    'AKUMULASI_KASUS': 440382,
#    'AKUMULASI_MENINGGAL': 6009,
#    'AKUMULASI_SEMBUH': 348312,
#    'DIRAWAT_OR_ISOLASI': 2274,
#    'KASUS': 7401,
#    'MENINGGAL': 160,
#    'SEMBUH': 4967,
#    'tanggal': 1625788800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 86830,
#    'AKUMULASI_KASUS': 445308,
#    'AKUMULASI_MENINGGAL': 6174,
#    'AKUMULASI_SEMBUH': 352304,
#    'DIRAWAT_OR_ISOLASI': 769,
#    'KASUS': 4926,
#    'MENINGGAL': 165,
#    'SEMBUH': 3992,
#    'tanggal': 1625875200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 89645,
#    'AKUMULASI_KASUS': 452012,
#    'AKUMULASI_MENINGGAL': 6445,
#    'AKUMULASI_SEMBUH': 355922,
#    'DIRAWAT_OR_ISOLASI': 2815,
#    'KASUS': 6704,
#    'MENINGGAL': 271,
#    'SEMBUH': 3618,
#    'tanggal': 1625961600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 92967,
#    'AKUMULASI_KASUS': 459951,
#    'AKUMULASI_MENINGGAL': 6616,
#    'AKUMULASI_SEMBUH': 360368,
#    'DIRAWAT_OR_ISOLASI': 3322,
#    'KASUS': 7939,
#    'MENINGGAL': 171,
#    'SEMBUH': 4446,
#    'tanggal': 1626048000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 95843,
#    'AKUMULASI_KASUS': 467144,
#    'AKUMULASI_MENINGGAL': 6760,
#    'AKUMULASI_SEMBUH': 364541,
#    'DIRAWAT_OR_ISOLASI': 2876,
#    'KASUS': 7193,
#    'MENINGGAL': 144,
#    'SEMBUH': 4173,
#    'tanggal': 1626134400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 102028,
#    'AKUMULASI_KASUS': 477588,
#    'AKUMULASI_MENINGGAL': 6902,
#    'AKUMULASI_SEMBUH': 368658,
#    'DIRAWAT_OR_ISOLASI': 6185,
#    'KASUS': 10444,
#    'MENINGGAL': 142,
#    'SEMBUH': 4117,
#    'tanggal': 1626220800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 107873,
#    'AKUMULASI_KASUS': 488687,
#    'AKUMULASI_MENINGGAL': 7028,
#    'AKUMULASI_SEMBUH': 373786,
#    'DIRAWAT_OR_ISOLASI': 5845,
#    'KASUS': 11099,
#    'MENINGGAL': 126,
#    'SEMBUH': 5128,
#    'tanggal': 1626307200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 111127,
#    'AKUMULASI_KASUS': 499416,
#    'AKUMULASI_MENINGGAL': 7165,
#    'AKUMULASI_SEMBUH': 381124,
#    'DIRAWAT_OR_ISOLASI': 3254,
#    'KASUS': 10729,
#    'MENINGGAL': 137,
#    'SEMBUH': 7338,
#    'tanggal': 1626393600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 115554,
#    'AKUMULASI_KASUS': 508815,
#    'AKUMULASI_MENINGGAL': 7249,
#    'AKUMULASI_SEMBUH': 386012,
#    'DIRAWAT_OR_ISOLASI': 4427,
#    'KASUS': 9399,
#    'MENINGGAL': 84,
#    'SEMBUH': 4888,
#    'tanggal': 1626480000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 119302,
#    'AKUMULASI_KASUS': 516591,
#    'AKUMULASI_MENINGGAL': 7340,
#    'AKUMULASI_SEMBUH': 389949,
#    'DIRAWAT_OR_ISOLASI': 3748,
#    'KASUS': 7776,
#    'MENINGGAL': 91,
#    'SEMBUH': 3937,
#    'tanggal': 1626566400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 121291,
#    'AKUMULASI_KASUS': 523879,
#    'AKUMULASI_MENINGGAL': 7422,
#    'AKUMULASI_SEMBUH': 395166,
#    'DIRAWAT_OR_ISOLASI': 1989,
#    'KASUS': 7288,
#    'MENINGGAL': 82,
#    'SEMBUH': 5217,
#    'tanggal': 1626652800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 125085,
#    'AKUMULASI_KASUS': 530807,
#    'AKUMULASI_MENINGGAL': 7492,
#    'AKUMULASI_SEMBUH': 398230,
#    'DIRAWAT_OR_ISOLASI': 3794,
#    'KASUS': 6928,
#    'MENINGGAL': 70,
#    'SEMBUH': 3064,
#    'tanggal': 1626739200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 124023,
#    'AKUMULASI_KASUS': 536757,
#    'AKUMULASI_MENINGGAL': 7611,
#    'AKUMULASI_SEMBUH': 405123,
#    'DIRAWAT_OR_ISOLASI': -1062,
#    'KASUS': 5950,
#    'MENINGGAL': 119,
#    'SEMBUH': 6893,
#    'tanggal': 1626825600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 127073,
#    'AKUMULASI_KASUS': 547256,
#    'AKUMULASI_MENINGGAL': 7752,
#    'AKUMULASI_SEMBUH': 412431,
#    'DIRAWAT_OR_ISOLASI': 3050,
#    'KASUS': 10499,
#    'MENINGGAL': 141,
#    'SEMBUH': 7308,
#    'tanggal': 1626912000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 128963,
#    'AKUMULASI_KASUS': 556181,
#    'AKUMULASI_MENINGGAL': 7908,
#    'AKUMULASI_SEMBUH': 419310,
#    'DIRAWAT_OR_ISOLASI': 1890,
#    'KASUS': 8925,
#    'MENINGGAL': 156,
#    'SEMBUH': 6879,
#    'tanggal': 1626998400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 129650,
#    'AKUMULASI_KASUS': 563768,
#    'AKUMULASI_MENINGGAL': 8023,
#    'AKUMULASI_SEMBUH': 426095,
#    'DIRAWAT_OR_ISOLASI': 687,
#    'KASUS': 7587,
#    'MENINGGAL': 115,
#    'SEMBUH': 6785,
#    'tanggal': 1627084800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 129690,
#    'AKUMULASI_KASUS': 569070,
#    'AKUMULASI_MENINGGAL': 8146,
#    'AKUMULASI_SEMBUH': 431234,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 5302,
#    'MENINGGAL': 123,
#    'SEMBUH': 5139,
#    'tanggal': 1627171200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 128945,
#    'AKUMULASI_KASUS': 573438,
#    'AKUMULASI_MENINGGAL': 8372,
#    'AKUMULASI_SEMBUH': 436121,
#    'DIRAWAT_OR_ISOLASI': -745,
#    'KASUS': 4368,
#    'MENINGGAL': 226,
#    'SEMBUH': 4887,
#    'tanggal': 1627257600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 127891,
#    'AKUMULASI_KASUS': 582027,
#    'AKUMULASI_MENINGGAL': 8681,
#    'AKUMULASI_SEMBUH': 445455,
#    'DIRAWAT_OR_ISOLASI': -1054,
#    'KASUS': 8589,
#    'MENINGGAL': 309,
#    'SEMBUH': 9334,
#    'tanggal': 1627344000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 127986,
#    'AKUMULASI_KASUS': 590393,
#    'AKUMULASI_MENINGGAL': 8886,
#    'AKUMULASI_SEMBUH': 453521,
#    'DIRAWAT_OR_ISOLASI': 95,
#    'KASUS': 8366,
#    'MENINGGAL': 205,
#    'SEMBUH': 8066,
#    'tanggal': 1627430400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 127451,
#    'AKUMULASI_KASUS': 597912,
#    'AKUMULASI_MENINGGAL': 9096,
#    'AKUMULASI_SEMBUH': 461365,
#    'DIRAWAT_OR_ISOLASI': -535,
#    'KASUS': 7519,
#    'MENINGGAL': 210,
#    'SEMBUH': 7844,
#    'tanggal': 1627516800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 126840,
#    'AKUMULASI_KASUS': 604824,
#    'AKUMULASI_MENINGGAL': 9184,
#    'AKUMULASI_SEMBUH': 468800,
#    'DIRAWAT_OR_ISOLASI': -611,
#    'KASUS': 6912,
#    'MENINGGAL': 88,
#    'SEMBUH': 7435,
#    'tanggal': 1627603200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 123928,
#    'AKUMULASI_KASUS': 609028,
#    'AKUMULASI_MENINGGAL': 9363,
#    'AKUMULASI_SEMBUH': 475737,
#    'DIRAWAT_OR_ISOLASI': -2912,
#    'KASUS': 4204,
#    'MENINGGAL': 179,
#    'SEMBUH': 6937,
#    'tanggal': 1627689600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 123056,
#    'AKUMULASI_KASUS': 611797,
#    'AKUMULASI_MENINGGAL': 9552,
#    'AKUMULASI_SEMBUH': 479189,
#    'DIRAWAT_OR_ISOLASI': -872,
#    'KASUS': 2769,
#    'MENINGGAL': 189,
#    'SEMBUH': 3452,
#    'tanggal': 1627776000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 119046,
#    'AKUMULASI_KASUS': 614138,
#    'AKUMULASI_MENINGGAL': 9679,
#    'AKUMULASI_SEMBUH': 485413,
#    'DIRAWAT_OR_ISOLASI': -4010,
#    'KASUS': 2341,
#    'MENINGGAL': 127,
#    'SEMBUH': 6224,
#    'tanggal': 1627862400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 118120,
#    'AKUMULASI_KASUS': 618439,
#    'AKUMULASI_MENINGGAL': 9818,
#    'AKUMULASI_SEMBUH': 490501,
#    'DIRAWAT_OR_ISOLASI': -926,
#    'KASUS': 4301,
#    'MENINGGAL': 139,
#    'SEMBUH': 5088,
#    'tanggal': 1627948800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 116590,
#    'AKUMULASI_KASUS': 622433,
#    'AKUMULASI_MENINGGAL': 9960,
#    'AKUMULASI_SEMBUH': 495883,
#    'DIRAWAT_OR_ISOLASI': -1530,
#    'KASUS': 3994,
#    'MENINGGAL': 142,
#    'SEMBUH': 5382,
#    'tanggal': 1628035200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 111498,
#    'AKUMULASI_KASUS': 627151,
#    'AKUMULASI_MENINGGAL': 10133,
#    'AKUMULASI_SEMBUH': 505520,
#    'DIRAWAT_OR_ISOLASI': -5092,
#    'KASUS': 4718,
#    'MENINGGAL': 173,
#    'SEMBUH': 9637,
#    'tanggal': 1628121600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 107944,
#    'AKUMULASI_KASUS': 631731,
#    'AKUMULASI_MENINGGAL': 10240,
#    'AKUMULASI_SEMBUH': 513547,
#    'DIRAWAT_OR_ISOLASI': -3554,
#    'KASUS': 4580,
#    'MENINGGAL': 107,
#    'SEMBUH': 8027,
#    'tanggal': 1628208000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 105944,
#    'AKUMULASI_KASUS': 634735,
#    'AKUMULASI_MENINGGAL': 10319,
#    'AKUMULASI_SEMBUH': 518472,
#    'DIRAWAT_OR_ISOLASI': -2000,
#    'KASUS': 3004,
#    'MENINGGAL': 79,
#    'SEMBUH': 4925,
#    'tanggal': 1628294400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 89321,
#    'AKUMULASI_KASUS': 636983,
#    'AKUMULASI_MENINGGAL': 10377,
#    'AKUMULASI_SEMBUH': 537285,
#    'DIRAWAT_OR_ISOLASI': -16623,
#    'KASUS': 2248,
#    'MENINGGAL': 58,
#    'SEMBUH': 18813,
#    'tanggal': 1628380800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 82815,
#    'AKUMULASI_KASUS': 639405,
#    'AKUMULASI_MENINGGAL': 10497,
#    'AKUMULASI_SEMBUH': 546093,
#    'DIRAWAT_OR_ISOLASI': -6506,
#    'KASUS': 2422,
#    'MENINGGAL': 120,
#    'SEMBUH': 8808,
#    'tanggal': 1628467200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 79042,
#    'AKUMULASI_KASUS': 643568,
#    'AKUMULASI_MENINGGAL': 10988,
#    'AKUMULASI_SEMBUH': 553538,
#    'DIRAWAT_OR_ISOLASI': -3773,
#    'KASUS': 4163,
#    'MENINGGAL': 491,
#    'SEMBUH': 7445,
#    'tanggal': 1628553600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 73976,
#    'AKUMULASI_KASUS': 646742,
#    'AKUMULASI_MENINGGAL': 11108,
#    'AKUMULASI_SEMBUH': 561658,
#    'DIRAWAT_OR_ISOLASI': -5066,
#    'KASUS': 3174,
#    'MENINGGAL': 120,
#    'SEMBUH': 8120,
#    'tanggal': 1628640000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 71229,
#    'AKUMULASI_KASUS': 648610,
#    'AKUMULASI_MENINGGAL': 11198,
#    'AKUMULASI_SEMBUH': 566183,
#    'DIRAWAT_OR_ISOLASI': -2747,
#    'KASUS': 1868,
#    'MENINGGAL': 90,
#    'SEMBUH': 4525,
#    'tanggal': 1628726400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 65364,
#    'AKUMULASI_KASUS': 651574,
#    'AKUMULASI_MENINGGAL': 11268,
#    'AKUMULASI_SEMBUH': 574942,
#    'DIRAWAT_OR_ISOLASI': -5865,
#    'KASUS': 2964,
#    'MENINGGAL': 70,
#    'SEMBUH': 8759,
#    'tanggal': 1628812800000}],
#  'meninggal_dengan_tgl': 11268,
#  'meninggal_persen': 1.7299646701679317,
#  'meninggal_tanpa_tgl': 4,
#  'provinsi': 'JAWA BARAT',
#  'sembuh_dengan_tgl': 574942,
#  'sembuh_persen': 88.39425759775558,
#  'sembuh_tanpa_tgl': 1012}

# %% [markdown]
# ***Memahami Kasus COVID-19 di Jawa Barat***
# Sekarang jalankanlah method keys() pada cov_jabar_raw tersebut untuk mengetahui nama-nama elemen utama yang tersedia dan jawablah pertanyaan berikut:
#
# Berapa jumlah total kasus COVID-19 di Jawa Barat?
# Berapa persentase kematian akibat COVID-19 di Jawa Barat?
# Berapa persentase tingkat kesembuhan dari COVID-19 di Jawa Barat?

# %%
print('Nama-nama elemen utama:\n', cov_jabar_raw.keys())
print('\nJumlah total kasus COVID-19 di Jawa Barat : %d' %cov_jabar_raw['kasus_total'])
print('Persentase kematian akibat COVID-19 di Jawa Barat : %f.2%%' %cov_jabar_raw['meninggal_persen'])
print('Persentase tingkat kesembuhan dari COVID-19 di Jawa Barat : %f.2%%' %cov_jabar_raw['sembuh_persen'])
# Out:
# Nama-nama elemen utama:
#  dict_keys(['last_date', 'provinsi', 'kasus_total', 'kasus_tanpa_tgl', 'kasus_dengan_tgl', 'meninggal_persen', 'meninggal_tanpa_tgl', 'meninggal_dengan_tgl', 'sembuh_persen', 'sembuh_tanpa_tgl', 'sembuh_dengan_tgl', 'list_perkembangan', 'data'])
#
# Jumlah total kasus COVID-19 di Jawa Barat : 651574
# Persentase kematian akibat COVID-19 di Jawa Barat : 1.729965.2%
# Persentase tingkat kesembuhan dari COVID-19 di Jawa Barat : 88.394258.2%

# %% [markdown]
# **Memperoleh Informasi yang Lebih Lengkap**
# Informasi umum mengenai COVID-19 di Jawa Barat telah Anda dapatkan. Namun informasi akan lebih lengkap jika Anda memiliki data perkembangan COVID-19 dari waktu ke waktu, apakah Anda setuju?
#
# Kabar baiknya adalah informasi tersebut juga disediakan oleh covid19.go.id melalui permintaan API yang telah Anda buat sebelumnya. Data historis perkembangan COVID-19 tersebut tersimpan dengan nama list_perkembangan. Silakan Anda ekstrak data tersebut dari cov_jabar_raw dan untuk lebih memudahkan dalam menginspeksi data ubahlah data bertipe dict ke pandas dataframe. Kemudian simpanlah hasilnya sebagai obyek bernama cov_jabar! Amati struktur cov_jabar menggunakan method info() dan head().

# %%
#import numpy as np
import pandas as pd
cov_jabar = pd.DataFrame(cov_jabar_raw['list_perkembangan'])
print('Info cov_jabar:\n', cov_jabar.info())
print('\nLima data teratas cov_jabar:\n', cov_jabar.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tanggal                       530 non-null    int64
#  1   KASUS                         530 non-null    int64
#  2   MENINGGAL                     530 non-null    int64
#  3   SEMBUH                        530 non-null    int64
#  4   DIRAWAT_OR_ISOLASI            530 non-null    int64
#  5   AKUMULASI_KASUS               530 non-null    int64
#  6   AKUMULASI_SEMBUH              530 non-null    int64
#  7   AKUMULASI_MENINGGAL           530 non-null    int64
#  8   AKUMULASI_DIRAWAT_OR_ISOLASI  530 non-null    int64
# dtypes: int64(9)
# memory usage: 37.4 KB
# Info cov_jabar:
#  None
#
# Lima data teratas cov_jabar:
#           tanggal  KASUS  ...  AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0  1583107200000      3  ...                    0                             3
# 1  1583193600000      1  ...                    1                             3
# 2  1583280000000      1  ...                    1                             4
# 3  1583366400000      1  ...                    1                             5
# 4  1583452800000      1  ...                    1                             6
#
# [5 rows x 9 columns]

# %% [markdown]
# Setelah mengekstrak dan mengamati cov_jabar, Anda menemukan beberapa kejanggalan pada data tersebut. Diantaranya adalah kejanggalan data pada kolom tanggal dan format penulisan** kolom yang tidak konsisten**. Sekarang Anda akan mencoba melakukan beberapa tahapan untuk menjinakan data tersebut sehingga dapat diolah dan dianalisis dengan lebih mudah.
#
# Ada beberapa tahapan yang akan Anda lakukan untuk menjinakan data cov_jabar, yaitu:
#
# 1.**Menghapus kolom DIRAWAT_OR_ISOLASI** dan semua kolom yang berisi nilai kumulatif
#
# 2.**Merubah format penulisan semua kolom menjadi huruf kecil**
#
# 3.**Mengganti nama kolom kasus menjadi kasus_baru**
#
#
# 4.**Memperbaiki tipe data pada kolom tanggal menggunakan pd.to_datetime**
#
#
#
#  Simpan hasil pengolahan Anda dengan nama cov_jabar_tidy.

# %%
 
#cov_jabar_tidy = (cov_jabar.drop(columns=[item for item in cov_jabar.columns
if item.startswith('AKUMULASI')
or item.startswith('DIRAWAT')])
.rename(columns=str.lower)
.rename(columns={'kasus': 'kasus_baru'})
)
cov_jabar_tidy['tanggal'] = pd.to_datetime(cov_jabar_tidy['tanggal']*1e6 )
print('Lima data teratas:\n', cov_jabar_tidy.head())
# Out:
#   File "<ipython-input-1-d0b306820130>", line 3
#     if item.startswith('AKUMULASI')
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ***Menunjukkan Melalui Gambar***
# Akhirnya Anda berhasil menjinakan data cov_jabar menjadi cov_jabar_tidy sehingga lebih mudah untuk diolah, selamat! Memiliki data yang rapi memang menyenangkan, apakah Anda setuju dengan hal tersebut?
#
# Setelah memiliki data yang jinak, sekarang saatnya Anda mengekspresikan data tersebut dalam bentuk lain yang harapannya lebih mudah dicerna: grafik. Anda akan memulai merancang visualisasi yang memiliki estetika dengan menggunakan library matplotlib. Imporlah library tersebut sebagai aliasnya!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ***Menunjukkan Melalui Gambar - 2***
# Berikut merupakan template kode untuk membuat visualisasi menggunakan matplotlib:
#
#
# Berdasarkan templat tersebut, komponen utama untuk membuat visualisasi antara lain adalah tabel data, kolom data, serta bentuk geometri untuk mempresentasikan data. Sebagai contoh untuk membuat scatter-plot yang diperlukan adalah bentuk geometri titik (.scatter()), line-chart memerlukan geometri garis (.plot()), sedangkan bar-chart memerlukan bentuk geometri batang atau kolom (.bar()).
#
# Lengkapi baris kode berikut untuk membuat bar-chart jumlah kasus baru harian COVID-19 di Jawa Barat menggunakan data cov_jabar_tidy! Pergunakan kolom tanggal sebagai sumbu-x.
#
# Kondisi COVID19 di Jawa Barat hingga Oktober 2020
#
# ![image.png](data:image/png;base64,...)
#
# dan untuk kondisi hingga awal Juli 2021
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.clf() #clearfigure
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='kasus_baru')
plt.show()

# %% [markdown]
# ***Informasi pada Grafik***
# Anda telah berhasil membuat bar-chart yang diminta. Namun grafik tersebut belum memiliki informasi yang jelas serta cenderung membosankan untuk dilihat. Sekarang silakan buat kembali grafik tersebut dengan menggunakan baris kode yang telah dimodifikasi berikut:
#
# Bar chart ini menunjukkan kondisi kasus harian postif COVID19 di Jawab Barat hingga Oktober 2020
# ![image.png](data:image/png;base64,...)
#
# Sementara itu, kondisi di awal Juli 2021 diperlihatkan berikut ini
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='kasus_baru', color='salmon')
fig.suptitle('Kasus Harian Positif COVID-19 di Jawa Barat',
y=1.00, fontsize=16, fontweight='bold', ha='center')
ax.set_title('Terjadi pelonjakan kasus di awal bulan Juli akibat klaster Secapa AD Bandung',
fontsize=10)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.3, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)
ax.set_xticklabels(ax.get_xticks(), rotation=90)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout() #https://matplotlib.org/stable/tutorials/intermediate/tight_layout_guide.html
plt.show()

# %% [markdown]
# ***Grafik untuk Kasus Sembuh***
# Sekarang buatlah grafik serupa dengan menggunakan data kasus sembuh menggunakan warna olivedrab!
#
# Untuk kasus harian sembuh dari COVID19 di Jawa Barat hingga Oktober 2020 ditunjukkan oleh grafik:

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='sembuh', color='olivedrab')
ax.set_title('Kasus Harian Sembuh Dari COVID-19 di Jawa Barat',
fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.3, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)
ax.set_xticklabels(ax.get_xticks(), rotation=90)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik untuk Kasus Meninggal
# Sekarang buatlah grafik serupa dengan menggunakan data kasus meninggal menggunakan warna slategrey!

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='meninggal', color='slategrey')
ax.set_title('Kasus Harian Meninggal Dari COVID-19 di Jawa Barat',
fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.3, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)
ax.set_xticklabels(ax.get_xticks(), rotation=90)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Apakah Pekan ini Lebih Baik?***
# Setelah mengamati grafik perkembangan kasus Anda menyadari bahwa terjadi fluktuasi pertambahan kasus harian. Dilandasi hal tersebut Anda kemudian ingin mencoba mengamati bagaimana perkembangan kasus dalam rentang waktu pekanan. Bagaimanakah caranya?
#
# Anda dapat dengan mudah mengerjakannya Anda sudah dibantu melalui predefined code, yaitu set terlebih dahulu kolom tanggal pada cov_jabar_tidy sebagai index. Kemudian terapkan method pada time series di pandas, resampling per pekan dan gunakan agregasi penjumlahan. Adapun yang akan digunakan untuk mengekstrak informasi pekan dalam satu tahun adalah weekofyear dan year untuk tahun.
#
# Lengkapilah baris kode berikut untuk menghitung pertambahan kasus pekanan dan simpanlah hasilnya sebagai cov_jabar_pekanan! Anda juga diminta untuk menggunakan method info() dan .head() untuk melakukan inspeksi data.

# %%
cov_jabar_pekanan = (cov_jabar_tidy.set_index('tanggal')['kasus_baru']
.resample('W')
.sum()
.reset_index()
.rename(columns={'kasus_baru': 'jumlah'})
)
cov_jabar_pekanan['tahun'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.year)
cov_jabar_pekanan['pekan_ke'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.weekofyear)
cov_jabar_pekanan = cov_jabar_pekanan[['tahun', 'pekan_ke', 'jumlah']]

print('Info cov_jabar_pekanan:')
print(cov_jabar_pekanan.info())
print('\nLima data teratas cov_jabar_pekanan:\n', cov_jabar_pekanan.head())
# Out:
# Info cov_jabar_pekanan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tahun     76 non-null     int64
#  1   pekan_ke  76 non-null     int64
#  2   jumlah    76 non-null     int64
# dtypes: int64(3)
# memory usage: 1.9 KB
# None
#
# Lima data teratas cov_jabar_pekanan:
#     tahun  pekan_ke  jumlah
# 0   2020        10       7
# 1   2020        11       5
# 2   2020        12      52
# 3   2020        13     104
# 4   2020        14     131

# %% [markdown]
# ***Menjawab Pertanyaan***
# Pertanyaan baru muncul di benak Anda setelah melakukan inspeksi terhadap data cov_jabar_pekanan tersebut: "Apakah pekan ini lebih baik dari pekan kemarin?"
#
# Demi menjawab hal tersebut Anda melakukan kalkulasi sederhana dengan tahapan berikut:
#
# Membuat kolom baru yang berisi jumlah kasus baru dalam satu pekan sebelumnya. Kolom ini diberi nama jumlah_pekanlalu.
# Mengganti nilai NaN pada kolom jumlah_pekanlalu dengan nilai 0
# Melakukan komparasi antara kolom jumlah dengan kolom jumlah_pekanlalu. Hasil komparasi ini disimpan dalam kolom baru dengan nama lebih_baik, isinya adalah True apabila jumlah kasus baru pekan ini lebih rendah dibandingkan jumlah kasus pekan lalu
# Lengkapilah baris predefined kode yang diberikan untuk mengerjakan tahapan yang telah Anda rencanakan! Anda akan menggunakan method shift() untuk membuat kolom jumlah_pekanlalu. Inspeksi hasil pekerjaan Anda dengan menggunakan head(10)!

# %%
cov_jabar_pekanan['jumlah_pekanlalu'] = cov_jabar_pekanan['jumlah'].shift().replace(np.nan, 0).astype(np.int)
cov_jabar_pekanan['lebih_baik'] = cov_jabar_pekanan['jumlah'] < cov_jabar_pekanan['jumlah_pekanlalu']

print('Sepuluh data teratas:\n', cov_jabar_pekanan.head(10))
# Out:
# Sepuluh data teratas:
#     tahun  pekan_ke  jumlah  jumlah_pekanlalu  lebih_baik
# 0   2020        10       7                 0       False
# 1   2020        11       5                 7        True
# 2   2020        12      52                 5       False
# 3   2020        13     104                52       False
# 4   2020        14     131               104       False
# 5   2020        15     235               131       False
# 6   2020        16     277               235       False
# 7   2020        17     216               277        True
# 8   2020        18     156               216        True
# 9   2020        19     367               156       False

# %% [markdown]
# ***Membuat Bar Chart***
# Anda sungguh luar biasa! Dengan menggunakan data hasil perhitungan tersebut maka sekarang Anda dapat membuat bar-chat penambahan kasus pekanan yang ditambahkan informasi baru untuk menjawab pertanyaan: "Apakah pekan ini lebih baik?"

# %%
import numpy as np
import pandas as pd
import requests
resp_jabar = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json')
cov_jabar_raw = resp_jabar.json()
cov_jabar = pd.DataFrame(cov_jabar_raw['list_perkembangan'])

cov_jabar_tidy = (cov_jabar.drop(columns=[item for item in cov_jabar.columns 
                                               if item.startswith('AKUMULASI') 
                                                  or item.startswith('DIRAWAT')])
                           .rename(columns=str.lower)
                           .rename(columns={'kasus': 'kasus_baru'})
                  )
cov_jabar_tidy['tanggal'] = pd.to_datetime(cov_jabar_tidy['tanggal']*1e6, unit='ns')

cov_jabar_pekanan = (cov_jabar_tidy.set_index('tanggal')['kasus_baru']
                                   .resample('W')
                                   .sum()
                                   .reset_index()
                                   .rename(columns={'kasus_baru': 'jumlah'})
                    )
cov_jabar_pekanan['tahun'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.year)
cov_jabar_pekanan['pekan_ke'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.weekofyear)
cov_jabar_pekanan = cov_jabar_pekanan[['tahun', 'pekan_ke', 'jumlah']]

cov_jabar_pekanan['jumlah_pekanlalu'] = cov_jabar_pekanan['jumlah'].shift().replace(np.nan, 0).astype(np.int)
cov_jabar_pekanan['lebih_baik'] = cov_jabar_pekanan['jumlah'] < cov_jabar_pekanan['jumlah_pekanlalu']

import matplotlib.pyplot as plt

plt.clf()
jml_tahun_terjadi_covid19 = cov_jabar_pekanan['tahun'].nunique()
tahun_terjadi_covid19 = cov_jabar_pekanan['tahun'].unique()
fig, axes = plt.subplots(nrows=jml_tahun_terjadi_covid19, 
                         figsize=(10,3*jml_tahun_terjadi_covid19))

fig.suptitle('Kasus Pekanan Positif COVID-19 di Jawa Barat', 
             y=1.00, fontsize=16, fontweight='bold', ha='center')
for i, ax in enumerate(axes):
    ax.bar(data=cov_jabar_pekanan.loc[cov_jabar_pekanan['tahun']==tahun_terjadi_covid19[i]], 
           x='pekan_ke', height='jumlah', 
           color=['mediumseagreen' if x is True else 'salmon' 
                  for x in cov_jabar_pekanan['lebih_baik']])
    if i == 0:
        ax.set_title('Kolom hijau menunjukan penambahan kasus baru lebih sedikit dibandingkan satu pekan sebelumnya',
                     fontsize=10)
    elif i == jml_tahun_terjadi_covid19-1:
        ax.text(1, -0.2, 'Sumber data: covid.19.go.id', color='blue',
            ha='right', transform=ax.transAxes)

    ax.set_xlim([0, 52.5])
    ax.set_ylim([0, max(cov_jabar_pekanan['jumlah'])])
    ax.set_xlabel('')
    ax.set_ylabel('Jumlah kasus %d'%(tahun_terjadi_covid19[i],))
    ax.grid(axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Pola dan Dinamika***
# Ada yang akhirnya sembuh, namun tak sedikit pula yang meninggal akibat COVID-19. Sementara itu penambahan kasus baru terus terjadi di masyarakat. Hal ini mungkin memicu pertanyaan lain di diri Anda: "Hingga saat ini ada berapa kasus yang masih aktif?"
#
# Aktif dalam artian sedang dalam perawatan atau isolasi.
#
# Informasi ini sebenarnya telah disediakan di dalam respon API covid19.go.id yang Anda minta. Namun tidak ada salahnya jika Anda mencoba menghitungnya sendiri, apakah Anda setuju?
#
# Jumlah kasus aktif dapat dihitung dengan cara mengurangi jumlah akumulasi positif dengan jumlah akumulasi sembuh dan jumlah akumulasi meninggal. Anda dapat menggunakan method cumsum() untuk menghitung nilai akumulasi dari suatu vektor numerik. Lengkapilah baris kode berikut untuk menghitung jumlah akumulasi kasus aktif, kasus sembuh, dan kasus meninggal!

# %%
cov_jabar_akumulasi = cov_jabar_tidy[['tanggal']].copy()
cov_jabar_akumulasi['akumulasi_aktif'] = (cov_jabar_tidy['kasus_baru'] - cov_jabar_tidy['sembuh'] - cov_jabar_tidy['meninggal']).cumsum()
cov_jabar_akumulasi['akumulasi_sembuh'] = cov_jabar_tidy['sembuh'].cumsum()
cov_jabar_akumulasi['akumulasi_meninggal'] = cov_jabar_tidy['meninggal'].cumsum()
print(cov_jabar_akumulasi.tail())
# Out:
#        tanggal  akumulasi_aktif  akumulasi_sembuh  akumulasi_meninggal
# 525 2021-08-09            82815            546093                10497
# 526 2021-08-10            79042            553538                10988
# 527 2021-08-11            73976            561658                11108
# 528 2021-08-12            71229            566183                11198
# 529 2021-08-13            65364            574942                11268

# %% [markdown]
# ***Membuat Line Chart***
# Sekarang cobalah Anda buat line-chart pola kasus aktif dengan menggunakan method plot pada ax
#
# Akumulasi COVID19 hingga Oktober 2020

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.plot('tanggal', 'akumulasi_aktif', data=cov_jabar_akumulasi, lw=2)

ax.set_title('Akumulasi aktif COVID-19 di Jawa Barat',
             fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Akumulasi aktif')
ax.text(1, -0.3, 'Sumber data: covid.19.go.id', color='blue',
        ha='right', transform=ax.transAxes)
ax.set_xticklabels(ax.get_xticks(), rotation=90)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Kabar Buruk dan Kabar Baik***
# Sebagai penutup analisis dalam proyek ini Anda diminta untuk membuat grafik komparasi antara akumulasi kasus aktif, kasus sembuh, dan kasus meninggal.
#
# Ada dua pilihan cara yang dapat Anda tempuh untuk membuat grafik tersebut:
#
# Menggunakan data frame cov_jabar_akumulasi, dengan kolom bertipe datetime diset menjadi index sehingga kita memiliki time series dataframe. Kemudian kita secara langsung dapat melakukan line plot dan memilih warna garis yang sesuai untuk membedakan; atau
# Menggunakan ax.plot() dan mengisikan kolom-kolom yang masing-masingnya menjadi x dan y dengan data=cov_jabar_akumulasi, dan kemudian menset warna berbeda untuk ketiga line plot.
# Anda akan diminta untuk menempuh cara nomor 1. Ketik True pada konsol jika Anda setuju!

# %%
true

# %% [markdown]
# ***Selamat ***Anda telah menyelesaikan proyek analisis COVID-19 ini! Anda telah berhasil melakukan impor data melalui API,
# melakukan transformasi data,
# serta membuat visualisasi untuk mengkomunikasikan hasil analisis data tentang COVID-19.
# Anda dipersilakan untuk selanjutnya mengembangkan analisis dengan cara mengambil studi kasus provinsi lain atau bahkan melakukan komparasi antar provinsi.
#
# Dengan berhasilnya Anda menyelesaikan proyek analisis ini, semoga Anda tetap sehat, waspada dan tetap tenang dalam menghadapi pandemi COVID-19. Selamat dan sukses selalu!
